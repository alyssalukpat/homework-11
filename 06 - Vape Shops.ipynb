# %% [markdown]
# # Scraping Maryland Business Licenses with Selenium
#
# Maryland has a [great portal](https://jportal.mdcourts.gov/license/pbPublicSearch.jsp) for searching business licenses, but the only problem is you have to check a box in order to get in.
#
# 1. Try to visit [the public search page](https://jportal.mdcourts.gov/license/pbPublicSearch.jsp)
# 2. Get redirected to a "I agree to this" page. Click that you've read the disclaimer, click Enter the Site.
# 3. Click "Search License Records" down at the bottom of the page
# 4. You're now on the search page! From the "Jurisdiction" dropdown, select "Statewide"
# 5. In the "Trade Name" field, type "Vap%" to try to find vape shops
# 6. Click "Next" in the bottom right-hand corner to go to the next page
# 7. Click "Click for detail" to see the details for a specific business license.
#
# That's a lot of stuff! **Let's get to work.**

# %% [markdown]
# ## Import what you need

# %%
import pandas as pd

from selenium import webdriver
driver = webdriver.Chrome()
driver.get("https://jportal.mdcourts.gov/license/pbPublicSearch.jsp")

# %%
# driver.get("https://jportal.mdcourts.gov/license/pbPublicSearch.jsp")

# %% [markdown]
# ## Preparation
#
# ### When you search for a business license, what URL should Selenium try to visit first?

# %%
# get past disclaimer page
box = driver.find_element_by_id('checkbox')
box.click()
submit_button = driver.find_elements_by_class_name('copy')[1].find_elements_by_tag_name('input')[1]
submit_button.click()

# %% [markdown]
# **It isn't going to work, though! It's going to redirect to that intro page.** You can use *Incognito mode* to go back through the "Check the box, etc" series of pages, or you can close and re-open Chrome.
#
# - Check the checkbox, then submit the form to accept their terms of service
#
# Selenium can submit forms by either
#
# - Selecting the form and using `.submit()`, or
# - Selecting the button and using `.click()`
#
# You only need to be able to get **one, not both.**
#
# - *TIP: if something doesn't have anything special about it, xpath might be your best bet*

# %% [markdown]
# Now click the **Search License Records** link up top in the navigation to get to the search page.
#
# - *TIP: Honestly you could also just visit the URL directly now since you filled out that terms of service thing*

# %%
# on new page, click on license search at bottom
get_license_search = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[6]/td[2]/a[2]')
get_license_search.click()

# %% [markdown]
# ### Perform your search
#
# Pick "Statewide" for the jurisdiction dropdown, and `VAP%` into the Trade Name field. The `%` is a wildcard.
#
# *TIP: I wish I could put this on CourseWorks, but it looks too ugly: [Selenium snippets](http://jonathansoma.com/lede/foundations-2018/classes/selenium/selenium-snippets/) will help you with the dropdown*

# %%
# on license search page, select dropdown and click. then select statewide and click
jurisdiction = driver.find_element_by_id('slcJurisdiction')
jurisdiction_click = jurisdiction.click()
statewide = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/form/table/tbody/tr[2]/td/select/option[2]')
statewide.click()

# %%
# select trade name field and type text
trade_name = driver.find_element_by_id('txtTradeName')
trade_name.click()
trade_name.send_keys('Vap%')

# %% [markdown]
# And now, of course, **submit the form**.
#
# - *TIP: Since scrolling to buttons can be a pain, sometimes it's easier to select the form and use `.submit()` instead of `.click()`ing the button*

# %%
# copied xpath for row with submit and reset buttons
driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/form/table/tbody/tr[14]').submit()

# %% [markdown]
# ## (Try to) scrape the results
#
# Let's start by just **printing this stuff**. We'll save it as a dataframe later on.
#
# For now, just scrape **each store's name**, then cry a little. Fact: this is an impossible and miserable page.

# %%
name_list = []
names_from_first_result_pg = driver.find_elements_by_class_name('searchlistitem')
for item in names_from_first_result_pg:
    name_list.append(item.text.strip())
name_list
# Out:
# ['VAPE IT STORE I',
#  'VAPE IT STORE II',
#  'VAPEPAD THE',
#  'VAPE LOFT THE',
#  'VAPE N CIGAR']

# %% [markdown]
# To avoid struggling with the search results page, we're going to use the **detail page** instead. Try to figure out how to select it and click it inside of your `for` loop.
#
# - *TIP: Instead of just looking for an `a` or an `img`, you might want to look for one of its parents first, then click. This might affect the way you print out the shop's name, too*
# - *TIP: Not all of them have links! You can wrap in try/except to skip it, or you can check to see if the shop's status is Pending.*

# %%
vape_table = driver.find_elements_by_tag_name('table')[2].find_elements_by_class_name('searchfieldtitle')

# %%
vape_table[4].find_elements_by_tag_name('td')[2].text.strip()
# Out:
# ''

# %%
pending_or_not_list = []
for item in vape_table:
    item_td = item.find_elements_by_tag_name('td')[2]
    pending_or_not_list.append(item_td.text.strip())
pending_or_not_list
# Out:
# ['Pending *', 'Pending *', '', '', '']

# %%
count = 0
for item in pending_or_not_list:
    vape_table = driver.find_elements_by_tag_name('table')[2].find_elements_by_class_name('searchfieldtitle')  
    item_td = vape_table[count].find_elements_by_tag_name('td')[2]
    if len(item) == 0:
#         url = item_td.find_element_by_tag_name('a').get_attribute('href')
#         driver.get(url)
        item_td.click()
        driver.back()
        print(count)
    count = count + 1
# Out:
# 2
# 3
# 4

# %% [markdown]
# Okay, now let's get to action. For each result, **click the link to the detail page** and print out the following information:
#
# - Mailing address
# - Location address
# - License information (you can keep it as one field)
# - Total amount paid
# - Issued by
# - If you're feeling crazy, get the licenses, too.
#
# If it doesn't have a detail page, just print out the name and that's all we need.
#
# - *TIP: `try`/`except` is probably going to be your friend. What's it do?
# - *TIP: When you're done getting the information, you probably want to click back to the search results*
# - *TIP: You might enjoy `find_element_by_partial_link_text` to do that*
# - *TIP: Licenses can be acquired by doing some really odd list slicing - think about where it starts and where it ends, relative to the beginning and end of everything.*
#
# > **IMPORTANT NOTE:** This is doomed!!!! It's useful to do, but your current process is doomed. Once you get a `stale element reference` error move on to the next cell.

# %%
count = 0
data = []
for item in pending_or_not_list:
    vape_table = driver.find_elements_by_tag_name('table')[2].find_elements_by_class_name('searchfieldtitle')  
    item_td = vape_table[count].find_elements_by_tag_name('td')[2]
#     print(item)
    try:
        if len(item) == 0:
            item_td.click()
    
            # once on the detail page...
            mailing_address = driver.find_element_by_class_name('tablecelltext').find_element_by_tag_name('td').text.strip()
            location_address = driver.find_elements_by_class_name('tablecelltext')[1].find_element_by_tag_name('td').text.strip()
            license_info = driver.find_elements_by_tag_name('table')[2].find_elements_by_tag_name('table')[0].find_elements_by_tag_name('tr')[2].find_elements_by_tag_name('td')[1].text.strip()
            amt_paid = driver.find_elements_by_tag_name('table')[2].find_elements_by_tag_name('table')[1].find_elements_by_tag_name('tr')[-1].find_elements_by_tag_name('td')[1].text.strip()
            issued_by = driver.find_elements_by_tag_name('table')[2].find_elements_by_tag_name('table')[2].find_elements_by_tag_name('tr')[1].text.strip()

            data.append({
            'mailing_address': mailing_address,
            'location_address': location_address,
            'license_info': license_info,
            'amt_paid': amt_paid,
            'issued_by': issued_by  
            }) 
            
            # to see if it's working:
            print("yes")
            
            driver.back()
            
    except:
        pass
    
    count = count + 1
# Out:
# yes
# yes
# yes

# %%
data
# Out:
# [{'mailing_address': 'ANJ DISTRIBUTIONS LLC\n2504 ORCHARD KNOLL WAY\nODENTON, MD 21113',
#   'location_address': 'VAPEPAD THE\n2299 JOHNS HOPKINS ROAD\nGAMBRILLS, MD 21054',
#   'license_info': 'License Status: Issued\nLicense No.: 02604406\nControl No.: 02685930\nDate of Issue: 5/01/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 02 Anne Arundel County',
#   'amt_paid': '$ 94.00',
#   'issued_by': 'SCOTT A. POYER, CLERK OF CIRCUIT COURT\n8 CHURCH CIRCLE, ROOM H-101\nANNAPOLIS, MARYLAND 21401'},
#  {'mailing_address': 'DISBROW II EMERSON HARRINGTON',
#   'location_address': 'VAPE LOFT THE\n167 MITCHELLS CHANCE ROAD\nEDGEWATER, MD 21037',
#   'license_info': 'License Status: Issued\nLicense No.: 02610340\nControl No.: 02686069\nDate of Issue: 4/09/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 02 Anne Arundel County',
#   'amt_paid': '$ 154.00',
#   'issued_by': 'SCOTT A. POYER, CLERK OF CIRCUIT COURT\n8 CHURCH CIRCLE, ROOM H-101\nANNAPOLIS, MARYLAND 21401'},
#  {'mailing_address': 'DISCOUNT TOBACCO EDGEWATER INC',
#   'location_address': 'VAPE N CIGAR\n12 MAYO ROAD\nEDGEWATER, MD 21037',
#   'license_info': 'License Status: Issued\nLicense No.: 02611281\nControl No.: 02611281\nDate of Issue: 5/05/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 02 Anne Arundel County',
#   'amt_paid': '$ 213.00',
#   'issued_by': 'SCOTT A. POYER, CLERK OF CIRCUIT COURT\n8 CHURCH CIRCLE, ROOM H-101\nANNAPOLIS, MARYLAND 21401'}]

# %% [markdown]
# ### Stale message reference
#
# Once you navigate away from a page, and you go back to it, you (sometimes, usually) can't use the variables from the first time you were on the page. So, we got a list of results when we first visited, clicked to the details page, clicked back, and now our original list is "stale."
#
# This is sad.
#
# Let's try this again: loop through the results and create a dataframe with `name` and `url` columns. And yes, some of them won't have URLs. No clicking links, just saving URLs.

# %%
vape_table = driver.find_elements_by_tag_name('table')[2].find_elements_by_class_name('searchfieldtitle')  

name_and_url = []
for item in vape_table:
    names_pg = item.find_element_by_class_name('searchlistitem').find_element_by_class_name('copybold').text.strip()
    link_finder = item.find_elements_by_tag_name('td')[2].text.strip()
    if len(link_finder) == 0:
        url = item.find_elements_by_tag_name('td')[2].find_element_by_tag_name('a').get_attribute('href')
    else:
        url = 'None'
    name_and_url.append({
        'name': names_pg,
        'url': url
    })

# %%
name_and_url
# Out:
# [{'name': 'VAPE IT STORE I', 'url': 'None'},
#  {'name': 'VAPE IT STORE II', 'url': 'None'},
#  {'name': 'VAPEPAD THE',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=ehvLau2KCoc%3D'},
#  {'name': 'VAPE LOFT THE',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=BXv1GksDAME%3D'},
#  {'name': 'VAPE N CIGAR',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=Zc3RGwRPTyM%3D'}]

# %% [markdown]
# ### Getting all of the results
#
# After you've looped through the results on one page, we're going to want to go to the next page! Add a line to make it click the 'Next' button down at the bottom
#
# - *TIP: `find_element_by_partial_link_text` will be your friend*
# - *TIP: You might need to do the scrolling thing to get it onto the screen (and by that I mean, you WILL need to, so you should)*
#
# Confirm that it moves to the next page (it doesn't need to scrape anything yet)

# %%
vape_table = driver.find_elements_by_tag_name('table')[2].find_elements_by_class_name('searchfieldtitle')  

name_and_url = []
for item in vape_table:
    names_pg = item.find_element_by_class_name('searchlistitem').find_element_by_class_name('copybold').text.strip()
    link_finder = item.find_elements_by_tag_name('td')[2].text.strip()
    if len(link_finder) == 0:
        url = item.find_elements_by_tag_name('td')[2].find_element_by_tag_name('a').get_attribute('href')
    else:
        url = 'None'
    name_and_url.append({
        'name': names_pg,
        'url': url
    })

next_pg = driver.find_element_by_partial_link_text('Next')
next_pg.click()

# %% [markdown]
# ### Wrapping with `while`
#
# > Go back to the first page of results before you try to run this
#
# You have a bunch of scraping code. It clicks the next button, then it stops. But you'd like it to go back up to the top! You can make that happen with a special `while` loop.
#
# ```python
# while True:
#     # Scrape your stuff
#     # Click next button
# ```
#
# This will go on FOREVER AND EVER until there is an error (when it can't find the Next button on the last page of results, you'll get a `NoSuchElement` error when it tries to find the next button).
#
# - *Tip: Print out "Scraping a new page" every time you visit a new page, just to check that it's working*

# %%
vape_table = driver.find_elements_by_tag_name('table')[2].find_elements_by_class_name('searchfieldtitle')  

name_and_url = []
while True:
    vape_table = driver.find_elements_by_tag_name('table')[2].find_elements_by_class_name('searchfieldtitle')  
    print("scraping new page")
    for item in vape_table:
        
        names_pg = item.find_element_by_class_name('searchlistitem').find_element_by_class_name('copybold').text.strip()
        link_finder = item.find_elements_by_tag_name('td')[2].text.strip()
        if len(link_finder) == 0:
            url = item.find_elements_by_tag_name('td')[2].find_element_by_tag_name('a').get_attribute('href')
        else:
            url = 'None'
        name_and_url.append({
            'name': names_pg,
            'url': url
        })

    next_pg = driver.find_element_by_partial_link_text('Next')
    next_pg.click()
# Out:
# scraping new page
# scraping new page
# scraping new page
# scraping new page
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-428-7f8272c703d9> in <module>
#      18         })
#      19
# ---> 20     next_pg = driver.find_element_by_partial_link_text('Next')
#      21     next_pg.click()
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_partial_link_text(self, link_text)
#     460             element = driver.find_element_by_partial_link_text('Sign')
#     461         """
# --> 462         return self.find_element(by=By.PARTIAL_LINK_TEXT, value=link_text)
#     463
#     464     def find_elements_by_partial_link_text(self, link_text):
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"partial link text","selector":"Next"}
#   (Session info: chrome=87.0.4280.88)

# %% [markdown]
# ### Making it perfect
#
# > Go back to the first page of results before you try to run this
#
# Wrap all of your code in a `try`/`except` so that it doesn't finish with an error and you'll be good to go.
#
# **Confirm your list has all of the vape shops in it.** If not, check where you are creating your empty list (`[]`) - if you do it in the wrong spot, it will overwrite your list every time you visit a page.

# %%
vape_table = driver.find_elements_by_tag_name('table')[2].find_elements_by_class_name('searchfieldtitle')  

name_and_url = []
try:
    while True:
        vape_table = driver.find_elements_by_tag_name('table')[2].find_elements_by_class_name('searchfieldtitle')  
        print("scraping new page")
        for item in vape_table:

            names_pg = item.find_element_by_class_name('searchlistitem').find_element_by_class_name('copybold').text.strip()
            link_finder = item.find_elements_by_tag_name('td')[2].text.strip()
            if len(link_finder) == 0:
                url = item.find_elements_by_tag_name('td')[2].find_element_by_tag_name('a').get_attribute('href')
            else:
                url = 'None'
            name_and_url.append({
                'name': names_pg,
                'url': url
            })

        next_pg = driver.find_element_by_partial_link_text('Next')
        next_pg.click()
except:
    pass
# Out:
# scraping new page
# scraping new page
# scraping new page
# scraping new page
# scraping new page

# %%
name_and_url
# Out:
# [{'name': 'VAPE IT STORE I', 'url': 'None'},
#  {'name': 'VAPE IT STORE II', 'url': 'None'},
#  {'name': 'VAPEPAD THE',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=ehvLau2KCoc%3D'},
#  {'name': 'VAPE LOFT THE',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=BXv1GksDAME%3D'},
#  {'name': 'VAPE N CIGAR',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=Zc3RGwRPTyM%3D'},
#  {'name': 'VAPE N CIGAR',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=e6HJxDrK5Rw%3D'},
#  {'name': 'VAPE DOJO', 'url': 'None'},
#  {'name': 'VAPE BIRD II',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=ZG6LP%2Fd39VU%3D'},
#  {'name': 'VAPE BIRD',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=gXLnULvwXBE%3D'},
#  {'name': 'VAPORFI SOUTHSIDE',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=tC7KTlcRVfw%3D'},
#  {'name': 'VAPE DO JO', 'url': 'None'},
#  {'name': 'VAPE PLANET',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=hvBqaR%2BpeVs%3D'},
#  {'name': 'VAPE PLUS', 'url': 'None'},
#  {'name': 'VAPE JUNGLE',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=jiwchRuFQoU%3D'},
#  {'name': 'VAPE JUNGLE 4',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=%2FwRoQ47y5O0%3D'},
#  {'name': 'VAPE SOCIAL',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=oFBW5u6f2is%3D'},
#  {'name': 'VAPE SWITCH', 'url': 'None'},
#  {'name': 'VAPEWERKS', 'url': 'None'},
#  {'name': 'VAPIST MD',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=6m9lvrjqnfo%3D'},
#  {'name': 'VAPOR EMPORIUM',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=qHyCfvsla4Q%3D'},
#  {'name': 'VAPOR VILLA',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=v6Es0Qnzy6M%3D'},
#  {'name': 'VAPOR VILLA',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=owKU%2FE0wQ0E%3D'},
#  {'name': 'VAPORS LOUNGE',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=jeQTUhWcuVA%3D'},
#  {'name': 'VAPERS RING THE',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=Rf2pM2eJw44%3D'}]

# %% [markdown]
# ### Save this data as a csv
#
# The filename should be `vape-shops-basic.csv`. You should have 24 rows.

# %%
df = pd.DataFrame(name_and_url)
df.head()
# Out:
#                name                                                url
# 0   VAPE IT STORE I                                               None
# 1  VAPE IT STORE II                                               None
# 2       VAPEPAD THE  https://jportal.mdcourts.gov/license/pbLicense...
# 3     VAPE LOFT THE  https://jportal.mdcourts.gov/license/pbLicense...
# 4      VAPE N CIGAR  https://jportal.mdcourts.gov/license/pbLicense...

# %%
df.to_csv('vape-shops-basic.csv', index=False)

# %% [markdown]
# # Okay, let's scrape!
#
# All right, get the actual data!
#
# ### Look at the URL of your first row
#
# - *TIP: Remember `pd.set_option('display.max_colwidth', None)` will let you see alllll of your strings*

# %%
# na_values='None' changes 'None' string to NaN
df2 = pd.read_csv('vape-shops-basic.csv', na_values='None')
pd.set_option('display.max_colwidth', None)
df2.head(1)
# Out:
#               name  url
# 0  VAPE IT STORE I  NaN

# %% [markdown]
# ### Okay, it doesn't have a URL!
#
# Let's drop all of the ones without URLs. You should be down to **17 rows**

# %%
df2 = df2[df2['url'].notna()]

# %% [markdown]
# Now look at the first one.

# %%
df2.head(1)
# Out:
#           name  \
# 2  VAPEPAD THE
#
#                                                                            url
# 2  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=ehvLau2KCoc%3D

# %% [markdown]
# ### Use Selenium to visit that page

# %%
# .iloc[0] means "give me the first row", kind of like .head(1), but
# it allows me to use .url to pull out the actual url. I only did this
# so that I could use a variable - you just needed to cut and paste
url = df2.iloc[0].url
url
# Out:
# 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=ehvLau2KCoc%3D'

# %% [markdown]
# ### Now, just like you did before, grab the additional data
#
# You should probably save it into a dictionary! Don't try to put it into the dataframe yet, though. You want:
#
# - Mailing address
# - Location address
# - License information (you can keep it as one field)
# - Total amount paid
# - Issued by
# - If you're feeling crazy, get the licenses, too.
#
# .
#
# - *TIP: Licenses can be acquired by doing some really odd list slicing - think about where it starts and where it ends, relative to the beginning and end of everything.*
# - *TIP: If you've gotten addicted to xpath, total amount paid and issued by might not work with it when doing other shops. You'll want to test it! It's because xpath relies on things like "it's the fourth row" but maybe there are more or fewer licenses sometimes, right? But you know it's always a certain number from the last row, so maybe use negative numbers with `.find_elements_by_...`? This is probably a confusing explanation.*

# %%
driver.get(url)

mailing_address = driver.find_element_by_class_name('tablecelltext').find_element_by_tag_name('td').text.strip()
location_address = driver.find_elements_by_class_name('tablecelltext')[1].find_elements_by_tag_name('td')[-1].text.strip()
license_info = driver.find_elements_by_tag_name('table')[2].find_elements_by_tag_name('table')[0].find_elements_by_tag_name('tr')[2].find_elements_by_tag_name('td')[1].text.strip()
amt_paid = driver.find_elements_by_tag_name('table')[2].find_elements_by_tag_name('table')[1].find_elements_by_tag_name('tr')[-1].find_elements_by_tag_name('td')[1].text.strip()
#     amt_paid = driver.find_elements_by_tag_name('table')[-1].find_elements_by_tag_name('table')[-3].find_elements_by_tag_name('tr')[-1].find_elements_by_tag_name('td')[-1].text.strip()
issued_by = driver.find_elements_by_tag_name('table')[2].find_elements_by_tag_name('table')[2].find_elements_by_tag_name('tr')[1].text.strip()
#     issued_by = driver.find_elements_by_tag_name('table')[-1].find_elements_by_tag_name('table')[-2].find_elements_by_tag_name('tr')[1].text.strip()

print(mailing_address)
print(location_address)
print(license_info)
print(amt_paid)
print(issued_by)
# Out:
# ANJ DISTRIBUTIONS LLC
# 2504 ORCHARD KNOLL WAY
# ODENTON, MD 21113
# VAPEPAD THE
# 2299 JOHNS HOPKINS ROAD
# GAMBRILLS, MD 21054
# License Status: Issued
# License No.: 02604406
# Control No.: 02685930
# Date of Issue: 5/01/2020
# Months Paid: 12
# Exp. Date: 4/30/2021
# Subdivision: 02 Anne Arundel County
# $ 94.00
# SCOTT A. POYER, CLERK OF CIRCUIT COURT
# 8 CHURCH CIRCLE, ROOM H-101
# ANNAPOLIS, MARYLAND 21401

# %% [markdown]
# ### Move all of this into one cell
#
# It should visit the URL, then grab the data and put it into a dictionary.

# %%
data2 = []

for item in df2['url']:
    driver.get(item)
    
    mailing_address = driver.find_element_by_class_name('tablecelltext').find_element_by_tag_name('td').text.strip()
    location_address = driver.find_elements_by_class_name('tablecelltext')[1].find_elements_by_tag_name('td')[-1].text.strip()
    license_info = driver.find_elements_by_tag_name('table')[2].find_elements_by_tag_name('table')[0].find_elements_by_tag_name('tr')[2].find_elements_by_tag_name('td')[1].text.strip()
    amt_paid = driver.find_elements_by_tag_name('table')[2].find_elements_by_tag_name('table')[1].find_elements_by_tag_name('tr')[-1].find_elements_by_tag_name('td')[1].text.strip()
    #     amt_paid = driver.find_elements_by_tag_name('table')[-1].find_elements_by_tag_name('table')[-3].find_elements_by_tag_name('tr')[-1].find_elements_by_tag_name('td')[-1].text.strip()
    issued_by = driver.find_elements_by_tag_name('table')[2].find_elements_by_tag_name('table')[2].find_elements_by_tag_name('tr')[1].text.strip()
#     issued_by = driver.find_elements_by_tag_name('table')[-1].find_elements_by_tag_name('table')[-2].find_elements_by_tag_name('tr')[1].text.strip()

    data2.append({
    'mailing_address': mailing_address,
    'location_address': location_address,
    'license_info': license_info,
    'amt_paid': amt_paid,
    'issued_by': issued_by,
    'url': item
    })

# %%
data2
# Out:
# [{'mailing_address': 'ANJ DISTRIBUTIONS LLC\n2504 ORCHARD KNOLL WAY\nODENTON, MD 21113',
#   'location_address': 'VAPEPAD THE\n2299 JOHNS HOPKINS ROAD\nGAMBRILLS, MD 21054',
#   'license_info': 'License Status: Issued\nLicense No.: 02604406\nControl No.: 02685930\nDate of Issue: 5/01/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 02 Anne Arundel County',
#   'amt_paid': '$ 94.00',
#   'issued_by': 'SCOTT A. POYER, CLERK OF CIRCUIT COURT\n8 CHURCH CIRCLE, ROOM H-101\nANNAPOLIS, MARYLAND 21401',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=ehvLau2KCoc%3D'},
#  {'mailing_address': 'DISBROW II EMERSON HARRINGTON',
#   'location_address': 'VAPE LOFT THE\n167 MITCHELLS CHANCE ROAD\nEDGEWATER, MD 21037',
#   'license_info': 'License Status: Issued\nLicense No.: 02610340\nControl No.: 02686069\nDate of Issue: 4/09/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 02 Anne Arundel County',
#   'amt_paid': '$ 154.00',
#   'issued_by': 'SCOTT A. POYER, CLERK OF CIRCUIT COURT\n8 CHURCH CIRCLE, ROOM H-101\nANNAPOLIS, MARYLAND 21401',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=BXv1GksDAME%3D'},
#  {'mailing_address': 'DISCOUNT TOBACCO EDGEWATER INC',
#   'location_address': 'VAPE N CIGAR\n12 MAYO ROAD\nEDGEWATER, MD 21037',
#   'license_info': 'License Status: Issued\nLicense No.: 02611281\nControl No.: 02611281\nDate of Issue: 5/05/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 02 Anne Arundel County',
#   'amt_paid': '$ 213.00',
#   'issued_by': 'SCOTT A. POYER, CLERK OF CIRCUIT COURT\n8 CHURCH CIRCLE, ROOM H-101\nANNAPOLIS, MARYLAND 21401',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=Zc3RGwRPTyM%3D'},
#  {'mailing_address': 'DISCOUNT TOBACCO ESSEX LLC',
#   'location_address': 'VAPE N CIGAR\n7104 MINSTREL UNIT #7\nCOLUMBIA, MD 21045',
#   'license_info': 'License Status: Issued\nLicense No.: 13640664\nControl No.: 13856368\nDate of Issue: 10/28/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 13 Howard County',
#   'amt_paid': '$ 135.00',
#   'issued_by': 'WAYNE A. ROBEY, CLERK OF CIRCUIT COURT\n6095 MARSHALEE DRIVE STE 120\nELKRIDGE, MARYLAND 21075',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=e6HJxDrK5Rw%3D'},
#  {'mailing_address': 'HEALTHIER CHOICES LLC\n356 ROMANCOKE ROAD\nSUITE 1\nSTEVENSVILLE, MD 21666',
#   'location_address': 'VAPE BIRD II\n2640 CENTREVILLE ROAD\nCENTREVILLE, MD 21617',
#   'license_info': 'License Status: Issued\nLicense No.: 17665504\nControl No.: 17368880\nDate of Issue: 7/09/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 17 Centreville',
#   'amt_paid': '$ 54.00',
#   'issued_by': 'KATHERINE B. HAGER, CLERK OF CIRCUIT COURT\n200 N. COMMERCE STREET\nCENTREVILLE, MARYLAND 21617',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=ZG6LP%2Fd39VU%3D'},
#  {'mailing_address': 'HUTCH VAPES LLC',
#   'location_address': 'VAPE BIRD\n356 ROMANCOKE ROAD SUITE 1\nSTEVENSVILLE, MD 21666',
#   'license_info': "License Status: Issued\nLicense No.: 17665514\nControl No.: 17980116\nDate of Issue: 7/21/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 17 Queen Anne's County",
#   'amt_paid': '$ 59.00',
#   'issued_by': 'KATHERINE B. HAGER, CLERK OF CIRCUIT COURT\n200 N. COMMERCE STREET\nCENTREVILLE, MARYLAND 21617',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=gXLnULvwXBE%3D'},
#  {'mailing_address': 'JEN S VAPOR LLC',
#   'location_address': 'VAPORFI SOUTHSIDE\n853 EAST FORT AVE\nBALTIMORE, MD 21230',
#   'license_info': 'License Status: Issued\nLicense No.: 30680742\nControl No.: 30190160\nDate of Issue: 5/15/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 30 Baltimore City',
#   'amt_paid': '$ 189.00',
#   'issued_by': 'MARILYN BENTLEY, CLERK CIRCUIT COURT\n100 N. CALVERT STREET, ROOM 627\nBALTIMORE, MARYLAND 21202',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=tC7KTlcRVfw%3D'},
#  {'mailing_address': 'RNS LLC',
#   'location_address': 'VAPE PLANET\n21632 GREAT MILLS ROAD\nLEXINGTON PARK, MD 20653',
#   'license_info': "License Status: Issued\nLicense No.: 18667704\nControl No.: 18667704\nDate of Issue: 7/14/2020\nMonths Paid: 10\nExp. Date: 4/30/2021\nSubdivision: 18 St. Mary's County",
#   'amt_paid': '$ 188.00',
#   'issued_by': 'Issued By',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=hvBqaR%2BpeVs%3D'},
#  {'mailing_address': 'VAPE JUNGLE LLC\n63 E CHESAPEAKE BEACH ROAD\nOWINGS, MD 20736',
#   'location_address': 'VAPE JUNGLE\n2070 CRAIN HIGHWAY UNIT F\nWALDORF, MD 20601',
#   'license_info': 'License Status: Issued\nLicense No.: 08630779\nControl No.: 08844059\nDate of Issue: 6/10/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 08 Charles County',
#   'amt_paid': '$ 186.00',
#   'issued_by': 'SHARON L. HANCOCK, CLERK OF CIRCUIT COURT\n200 CHARLES STREET\nLA PLATA, MARYLAND 20646',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=jiwchRuFQoU%3D'},
#  {'mailing_address': 'VAPE JUNGLE LLC\n63 E CHESAPEAKE BEACH RD\nOWINGS, MD 20736',
#   'location_address': 'VAPE JUNGLE 4\n5486 SOUTHERN MD BLVD\nLOTHIAN, MD 20711',
#   'license_info': 'License Status: Issued\nLicense No.: 02611618\nControl No.: 02611618\nDate of Issue: 10/14/2020\nMonths Paid: 7\nExp. Date: 4/30/2021\nSubdivision: 02 Anne Arundel County',
#   'amt_paid': '$ 99.75',
#   'issued_by': 'SCOTT A. POYER, CLERK OF CIRCUIT COURT\n8 CHURCH CIRCLE, ROOM H-101\nANNAPOLIS, MARYLAND 21401',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=%2FwRoQ47y5O0%3D'},
#  {'mailing_address': 'VAPE SOCIAL LLC',
#   'location_address': 'VAPE SOCIAL\n16521 S FREDERICK AVE\nGAITHERSBURG, MD 20877',
#   'license_info': 'License Status: Issued\nLicense No.: 15653996\nControl No.: 15728050\nDate of Issue: 7/28/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 15 Gaithersburg',
#   'amt_paid': '$ 59.00',
#   'issued_by': 'BARBARA H. MEIKLEJOHN, CLERK OF CIRCUIT COURT\n50 MARYLAND AVENUE, ROOM 1300\nROCKVILLE, MARYLAND 20850',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=oFBW5u6f2is%3D'},
#  {'mailing_address': 'VAPIST MD LLC\n2119 CREEKS EDGE LANE\nWALDORF, MD 20601',
#   'location_address': 'VAPIST MD\n6321 OLD BRANCH AVE\nCAMP SPRINGS, MD 20748',
#   'license_info': "License Status: Issued\nLicense No.: 16664255\nControl No.: 16166805\nDate of Issue: 8/26/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 16 Prince George's County",
#   'amt_paid': '$ 329.00',
#   'issued_by': 'MAHASIN EL AMIN, CLERK OF CIRCUIT COURT\n14735 MAIN STREET\nUPPER MARLBORO, MARYLAND 20772-9987',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=6m9lvrjqnfo%3D'},
#  {'mailing_address': 'VAPOR EMPORIUM MD LLC',
#   'location_address': 'VAPOR EMPORIUM\n11717 OLD NATIONAL PIKE\nUNIT 3B\nNEW MARKET, MD 21774',
#   'license_info': 'License Status: Issued\nLicense No.: 10634794\nControl No.: 10954003\nDate of Issue: 4/24/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 10 Frederick County',
#   'amt_paid': '$ 154.00',
#   'issued_by': 'SANDRA DALTON, CLERK OF CIRCUIT COURT\n100 WEST PATRICK STREET\nFREDERICK, MARYLAND 21701',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=qHyCfvsla4Q%3D'},
#  {'mailing_address': 'VAPOR VILLA CORP',
#   'location_address': 'VAPOR VILLA\n730 FREDERICK ROAD\nSUITE 202\nCATONSVILLE, MD 21228',
#   'license_info': 'License Status: Issued\nLicense No.: 03622173\nControl No.: 03696931\nDate of Issue: 5/06/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 03 Baltimore County',
#   'amt_paid': '$ 83.00',
#   'issued_by': 'JULIE L. ENSOR, CLERK OF CIRCUIT COURT\nP.O. Box 6754\nTOWSON, MARYLAND 21285-6754',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=v6Es0Qnzy6M%3D'},
#  {'mailing_address': 'VAPOR VILLA CORP',
#   'location_address': 'VAPOR VILLA\n1913 LANSDOWNE ROAD\nSUITE E\nBALTIMORE, MD 21227',
#   'license_info': 'License Status: Issued\nLicense No.: 03622172\nControl No.: 03696574\nDate of Issue: 5/06/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 03 Baltimore County',
#   'amt_paid': '$ 83.00',
#   'issued_by': 'JULIE L. ENSOR, CLERK OF CIRCUIT COURT\nP.O. Box 6754\nTOWSON, MARYLAND 21285-6754',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=owKU%2FE0wQ0E%3D'},
#  {'mailing_address': 'VAPORS LOUNGE LLC',
#   'location_address': 'VAPORS LOUNGE\n28943 THREE NOTCH ROAD\nMECHANICSVILLE, MD 20659',
#   'license_info': "License Status: Issued\nLicense No.: 18667461\nControl No.: 18877819\nDate of Issue: 5/26/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 18 St. Mary's County",
#   'amt_paid': '$ 94.00',
#   'issued_by': 'DEBRA J. BURCH CLERK OF CIRCUIT COURT\n41605 COURTHOUSE DRIVE, PO BOX 676\nLEONARDTOWN, MARYLAND 20650',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=jeQTUhWcuVA%3D'},
#  {'mailing_address': 'YEAGER ONE INC\n545 HIGGINS DR\nODENTON, MD 21113',
#   'location_address': 'VAPERS RING THE\n1159 ANNAPOLIS RD\nSUITE A\nODENTON, MD 21113',
#   'license_info': 'License Status: Issued\nLicense No.: 02610667\nControl No.: 02931736\nDate of Issue: 5/26/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 02 Anne Arundel County',
#   'amt_paid': '$ 154.00',
#   'issued_by': 'SCOTT A. POYER, CLERK OF CIRCUIT COURT\n8 CHURCH CIRCLE, ROOM H-101\nANNAPOLIS, MARYLAND 21401',
#   'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=Rf2pM2eJw44%3D'}]

# %% [markdown]
# ### Change it into a function
#
# You'll want to have this function accept a `row`, and send back a `pd.Series`. You can just use `pd.Series(your_dictionary)` (but it better have a better name than `your_dictionary`!).
#
# - *TIP: Make sure you `return` something!*
# - *TIP: Make sure you change everything to reflect the row's url, not the URL you typed in*

# %%
data3 = {}
def scrape_url(data2):
    url = data2['url']
    driver.get(url)
    
    mailing_address = driver.find_element_by_class_name('tablecelltext').find_element_by_tag_name('td').text.strip()
    location_address = driver.find_elements_by_class_name('tablecelltext')[1].find_elements_by_tag_name('td')[-1].text.strip()
    license_info = driver.find_elements_by_tag_name('table')[2].find_elements_by_tag_name('table')[0].find_elements_by_tag_name('tr')[2].find_elements_by_tag_name('td')[1].text.strip()
    amt_paid = driver.find_elements_by_tag_name('table')[2].find_elements_by_tag_name('table')[1].find_elements_by_tag_name('tr')[-1].find_elements_by_tag_name('td')[1].text.strip()
    #     amt_paid = driver.find_elements_by_tag_name('table')[-1].find_elements_by_tag_name('table')[-3].find_elements_by_tag_name('tr')[-1].find_elements_by_tag_name('td')[-1].text.strip()
#     issued_by = driver.find_elements_by_tag_name('table')[2].find_elements_by_tag_name('table')[2].find_elements_by_tag_name('tr')[1].text.strip()
    issued_by = driver.find_elements_by_tag_name('table')[-3].find_elements_by_tag_name('tr')[-1].text.strip()
    
    # vape social had an extra table at the bottom, so this is telling the function to go one table up to get the right info
    if issued_by == '« Return to List   New Search »':
        issued_by = driver.find_elements_by_tag_name('table')[-4].find_elements_by_tag_name('tr')[-1].text.strip()

##     issued_by = driver.find_elements_by_tag_name('table')[-1].find_elements_by_tag_name('table')[-2].find_elements_by_tag_name('tr')[1].text.strip()
    
    data3['mailing_address'] = mailing_address
    data3['location_address'] = location_address
    data3['license_info'] = license_info
    data3['amt_paid'] = amt_paid
    data3['issued_by'] = issued_by
    data3['url'] = url
    
    
    return pd.Series(data3)

# %% [markdown]
# ### Use your dataframe and `.apply` to pull all of the data from the vape shops
#
# Once you know it's working, use the whole
#
# - *TIP: Try using it with `.head(3)` first*
# - *TIP: You'll want to use `.apply` with your new function*
# - *TIP: Issued By and Total Paid are goign to give you problems if you tried to use xpath! Try checking the classes and think about find_elementSSSSS and working backwards instead of forwards.*
# - *TIP: You might need a `try`/`except`*
# - *TIP: Make sure you're using `axis=1`*
# - *TIP: Use `.join` the big thing with all of the `dfs` - make sure you name them right!*

# %%
# test
scrape_url({'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=oFBW5u6f2is%3D'})
# Out:
# mailing_address                                                                                                                                                         VAPE SOCIAL LLC
# location_address                                                                                                             VAPE SOCIAL\n16521 S FREDERICK AVE\nGAITHERSBURG, MD 20877
# license_info        License Status: Issued\nLicense No.: 15653996\nControl No.: 15728050\nDate of Issue: 7/28/2020\nMonths Paid: 12\nExp. Date: 4/30/2021\nSubdivision: 15 Gaithersburg
# amt_paid                                                                                                                                                                        $ 59.00
# issued_by                                                                       BARBARA H. MEIKLEJOHN, CLERK OF CIRCUIT COURT\n50 MARYLAND AVENUE, ROOM 1300\nROCKVILLE, MARYLAND 20850
# url                                                                                                         https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=oFBW5u6f2is%3D
# dtype: object

# %%
df3 = df2.apply(scrape_url, axis=1)

# %%
df3
# Out:
#                                                                mailing_address  \
# 2             ANJ DISTRIBUTIONS LLC\n2504 ORCHARD KNOLL WAY\nODENTON, MD 21113
# 3                                                DISBROW II EMERSON HARRINGTON
# 4                                               DISCOUNT TOBACCO EDGEWATER INC
# 5                                                   DISCOUNT TOBACCO ESSEX LLC
# 7   HEALTHIER CHOICES LLC\n356 ROMANCOKE ROAD\nSUITE 1\nSTEVENSVILLE, MD 21666
# 8                                                              HUTCH VAPES LLC
# 9                                                              JEN S VAPOR LLC
# 11                                                                     RNS LLC
# 13               VAPE JUNGLE LLC\n63 E CHESAPEAKE BEACH ROAD\nOWINGS, MD 20736
# 14                 VAPE JUNGLE LLC\n63 E CHESAPEAKE BEACH RD\nOWINGS, MD 20736
# 15                                                             VAPE SOCIAL LLC
# 18                     VAPIST MD LLC\n2119 CREEKS EDGE LANE\nWALDORF, MD 20601
# 19                                                       VAPOR EMPORIUM MD LLC
# 20                                                            VAPOR VILLA CORP
# 21                                                            VAPOR VILLA CORP
# 22                                                           VAPORS LOUNGE LLC
# 23                           YEAGER ONE INC\n545 HIGGINS DR\nODENTON, MD 21113
#
#                                                           location_address  \
# 2                VAPEPAD THE\n2299 JOHNS HOPKINS ROAD\nGAMBRILLS, MD 21054
# 3            VAPE LOFT THE\n167 MITCHELLS CHANCE ROAD\nEDGEWATER, MD 21037
# 4                          VAPE N CIGAR\n12 MAYO ROAD\nEDGEWATER, MD 21037
# 5                  VAPE N CIGAR\n7104 MINSTREL UNIT #7\nCOLUMBIA, MD 21045
# 7               VAPE BIRD II\n2640 CENTREVILLE ROAD\nCENTREVILLE, MD 21617
# 8            VAPE BIRD\n356 ROMANCOKE ROAD SUITE 1\nSTEVENSVILLE, MD 21666
# 9                VAPORFI SOUTHSIDE\n853 EAST FORT AVE\nBALTIMORE, MD 21230
://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=ZG6LP%2Fd39VU%3D
# 8     https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=gXLnULvwXBE%3D
# 9     https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=tC7KTlcRVfw%3D
# 11  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=hvBqaR%2BpeVs%3D
# 13    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=jiwchRuFQoU%3D
# 14  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=%2FwRoQ47y5O0%3D
# 15    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=oFBW5u6f2is%3D
# 18    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=6m9lvrjqnfo%3D
# 19    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=qHyCfvsla4Q%3D
# 20    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=v6Es0Qnzy6M%3D
# 21  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=owKU%2FE0wQ0E%3D
# 22    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=jeQTUhWcuVA%3D
# 23    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=Rf2pM2eJw44%3D

# %%
# need to regex the amount paid column
import re

# %%
clean_amt_paid = []
amt_paid_regex = r"\$ (.*)"
for item in df3['amt_paid']:
    clean_amt_paid.append(re.findall(amt_paid_regex,item))

clean_amt_paid2 = []
for item in clean_amt_paid:
    for thing in item:
        clean_amt_paid2.append(thing)
clean_amt_paid2
# Out:
# ['94.00',
#  '154.00',
#  '213.00',
#  '135.00',
#  '54.00',
#  '59.00',
#  '189.00',
#  '188.00',
#  '186.00',
#  '99.75',
#  '59.00',
#  '329.00',
#  '154.00',
#  '83.00',
#  '83.00',
#  '94.00',
#  '154.00']

# %%
df3['actual_amount_paid'] = clean_amt_paid2

# %%
del df3['amt_paid']

# %%
df3
# Out:
#                                                                mailing_address  \
# 2             ANJ DISTRIBUTIONS LLC\n2504 ORCHARD KNOLL WAY\nODENTON, MD 21113
# 3                                                DISBROW II EMERSON HARRINGTON
# 4                                               DISCOUNT TOBACCO EDGEWATER INC
# 5                                                   DISCOUNT TOBACCO ESSEX LLC
# 7   HEALTHIER CHOICES LLC\n356 ROMANCOKE ROAD\nSUITE 1\nSTEVENSVILLE, MD 21666
# 8                                                              HUTCH VAPES LLC
# 9                                                              JEN S VAPOR LLC
# 11                                                                     RNS LLC
# 13               VAPE JUNGLE LLC\n63 E CHESAPEAKE BEACH ROAD\nOWINGS, MD 20736
# 14                 VAPE JUNGLE LLC\n63 E CHESAPEAKE BEACH RD\nOWINGS, MD 20736
# 15                                                             VAPE SOCIAL LLC
# 18                     VAPIST MD LLC\n2119 CREEKS EDGE LANE\nWALDORF, MD 20601
# 19                                                       VAPOR EMPORIUM MD LLC
# 20                                                            VAPOR VILLA CORP
# 21                                                            VAPOR VILLA CORP
# 22                                                           VAPORS LOUNGE LLC
# 23                           YEAGER ONE INC\n545 HIGGINS DR\nODENTON, MD 21113
#
#                                                           location_address  \
# 2                VAPEPAD THE\n2299 JOHNS HOPKINS ROAD\nGAMBRILLS, MD 21054
# 3            VAPE LOFT THE\n167 MITCHELLS CHANCE ROAD\nEDGEWATER, MD 21037
# 4                          VAPE N CIGAR\n12 MAYO ROAD\nEDGEWATER, MD 21037
# 5                  VAPE N CIGAR\n7104 MINSTREL UNIT #7\nCOLUMBIA, MD 21045
# 7               VAPE BIRD II\n2640 CENTREVILLE ROAD\nCENTREVILLE, MD 21617
# 8            VAPE BIRD\n356 ROMANCOKE ROAD SUITE 1\nSTEVENSVILLE, MD 21666
# 9                VAPORFI SOUTHSIDE\n853 EAST FORT AVE\nBALTIMORE, MD 21230
https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=v6Es0Qnzy6M%3D
# 21  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=owKU%2FE0wQ0E%3D
# 22    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=jeQTUhWcuVA%3D
# 23    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=Rf2pM2eJw44%3D
#
#    actual_amount_paid
# 2               94.00
# 3              154.00
# 4              213.00
# 5              135.00
# 7               54.00
# 8               59.00
# 9              189.00
# 11             188.00
# 13             186.00
# 14              99.75
# 15              59.00
# 18             329.00
# 19             154.00
# 20              83.00
# 21              83.00
# 22              94.00
# 23             154.00

# %%
df3['actual_amount_paid'] = pd.to_numeric(df3["actual_amount_paid"])

# %%
df3
# Out:
#                                                                mailing_address  \
# 2             ANJ DISTRIBUTIONS LLC\n2504 ORCHARD KNOLL WAY\nODENTON, MD 21113
# 3                                                DISBROW II EMERSON HARRINGTON
# 4                                               DISCOUNT TOBACCO EDGEWATER INC
# 5                                                   DISCOUNT TOBACCO ESSEX LLC
# 7   HEALTHIER CHOICES LLC\n356 ROMANCOKE ROAD\nSUITE 1\nSTEVENSVILLE, MD 21666
# 8                                                              HUTCH VAPES LLC
# 9                                                              JEN S VAPOR LLC
# 11                                                                     RNS LLC
# 13               VAPE JUNGLE LLC\n63 E CHESAPEAKE BEACH ROAD\nOWINGS, MD 20736
# 14                 VAPE JUNGLE LLC\n63 E CHESAPEAKE BEACH RD\nOWINGS, MD 20736
# 15                                                             VAPE SOCIAL LLC
# 18                     VAPIST MD LLC\n2119 CREEKS EDGE LANE\nWALDORF, MD 20601
# 19                                                       VAPOR EMPORIUM MD LLC
# 20                                                            VAPOR VILLA CORP
# 21                                                            VAPOR VILLA CORP
# 22                                                           VAPORS LOUNGE LLC
# 23                           YEAGER ONE INC\n545 HIGGINS DR\nODENTON, MD 21113
#
#                                                           location_address  \
# 2                VAPEPAD THE\n2299 JOHNS HOPKINS ROAD\nGAMBRILLS, MD 21054
# 3            VAPE LOFT THE\n167 MITCHELLS CHANCE ROAD\nEDGEWATER, MD 21037
# 4                          VAPE N CIGAR\n12 MAYO ROAD\nEDGEWATER, MD 21037
# 5                  VAPE N CIGAR\n7104 MINSTREL UNIT #7\nCOLUMBIA, MD 21045
# 7               VAPE BIRD II\n2640 CENTREVILLE ROAD\nCENTREVILLE, MD 21617
# 8            VAPE BIRD\n356 ROMANCOKE ROAD SUITE 1\nSTEVENSVILLE, MD 21666
# 9                VAPORFI SOUTHSIDE\n853 EAST FORT AVE\nBALTIMORE, MD 21230
# 11           VAPE PLANET\n21632 GREAT MILLS ROAD\nLEXINGTON PARK, MD 20653
# 13               VAPE JUNGLE\n2070 CRAIN HIGHWAY UNIT F\nWALDORF, MD 20601
# 14                 VAPE JUNGLE 4\n5486 SOUTHERN MD BLVD\nLOTHIAN, MD 20711
# 15              VAPE SOCIAL\n16521 S FREDERICK AVE\nGAITHERSBURG, MD 20877
# 18                  VAPIST MD\n6321 OLD BRANCH AVE\nCAMP SPRINGS, MD 20748
# 19  VAPOR EMPORIUM\n11717 OLD NATIONAL PIKE\nUNIT 3B\nNEW MARKET, MD 21774
# 20       VAPOR VILLA\n730 FREDERICK ROAD\nSUITE 202\nCATONSVILLE, MD 21228
# 7           KATHERINE B. HAGER, CLERK OF CIRCUIT COURT\n200 N. COMMERCE STREET\nCENTREVILLE, MARYLAND 21617
# 8           KATHERINE B. HAGER, CLERK OF CIRCUIT COURT\n200 N. COMMERCE STREET\nCENTREVILLE, MARYLAND 21617
# 9          MARILYN BENTLEY, CLERK CIRCUIT COURT\n100 N. CALVERT STREET, ROOM 627\nBALTIMORE, MARYLAND 21202
# 11   DEBRA J. BURCH CLERK OF CIRCUIT COURT\n41605 COURTHOUSE DRIVE, PO BOX 676\nLEONARDTOWN, MARYLAND 20650
# 13                  SHARON L. HANCOCK, CLERK OF CIRCUIT COURT\n200 CHARLES STREET\nLA PLATA, MARYLAND 20646
# 14           SCOTT A. POYER, CLERK OF CIRCUIT COURT\n8 CHURCH CIRCLE, ROOM H-101\nANNAPOLIS, MARYLAND 21401
# 15  BARBARA H. MEIKLEJOHN, CLERK OF CIRCUIT COURT\n50 MARYLAND AVENUE, ROOM 1300\nROCKVILLE, MARYLAND 20850
# 18          MAHASIN EL AMIN, CLERK OF CIRCUIT COURT\n14735 MAIN STREET\nUPPER MARLBORO, MARYLAND 20772-9987
# 19                SANDRA DALTON, CLERK OF CIRCUIT COURT\n100 WEST PATRICK STREET\nFREDERICK, MARYLAND 21701
# 20                       JULIE L. ENSOR, CLERK OF CIRCUIT COURT\nP.O. Box 6754\nTOWSON, MARYLAND 21285-6754
# 21                       JULIE L. ENSOR, CLERK OF CIRCUIT COURT\nP.O. Box 6754\nTOWSON, MARYLAND 21285-6754
# 22   DEBRA J. BURCH CLERK OF CIRCUIT COURT\n41605 COURTHOUSE DRIVE, PO BOX 676\nLEONARDTOWN, MARYLAND 20650
# 23           SCOTT A. POYER, CLERK OF CIRCUIT COURT\n8 CHURCH CIRCLE, ROOM H-101\nANNAPOLIS, MARYLAND 21401
#
#                                                                               url  \
# 2     https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=ehvLau2KCoc%3D
# 3     https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=BXv1GksDAME%3D
# 4     https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=Zc3RGwRPTyM%3D
# 5     https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=e6HJxDrK5Rw%3D
# 7   https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=ZG6LP%2Fd39VU%3D
# 8     https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=gXLnULvwXBE%3D
# 9     https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=tC7KTlcRVfw%3D
# 11  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=hvBqaR%2BpeVs%3D
# 13    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=jiwchRuFQoU%3D
# 14  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=%2FwRoQ47y5O0%3D
# 15    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=oFBW5u6f2is%3D
# 18    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=6m9lvrjqnfo%3D
# 19    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=qHyCfvsla4Q%3D
# 20    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=v6Es0Qnzy6M%3D
# 21  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=owKU%2FE0wQ0E%3D
# 22    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=jeQTUhWcuVA%3D
# 23    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=Rf2pM2eJw44%3D
#
#     actual_amount_paid
# 2                94.00
# 3               154.00
# 4               213.00
# 5               135.00
# 7                54.00
# 8                59.00
# 9               189.00
# 11              188.00
# 13              186.00
# 14               99.75
# 15               59.00
# 18              329.00
# 19              154.00
# 20               83.00
# 21               83.00
# 22               94.00
# 23              154.00

# %% [markdown]
# ## Save as `vape-total.csv`
#
# Make sure you don't save the index! Open it up in a text editor or Excel to make sure it's correct.

# %%
df3.to_csv('vape-total.csv', index=False)
