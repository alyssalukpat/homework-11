# %% [markdown]
# # Rock and Mineral Clubs
#
# Scrape all of the rock and mineral clubs listed at https://rocktumbler.com/blog/rock-and-mineral-clubs/ (but don't just cut and paste!)
#
# Save a CSV called `rock-clubs.csv` with the name of the club, their URL, and the city they're located in.
#
# **Bonus**: Add a column for the state. There are a few ways to do this, but knowing that `element.parent` goes 'up' one element might be helpful.
#
# * _**Hint:** The name of the club and the city are both inside of td elements, and they aren't distinguishable by class. Instead you'll just want to ask for all of the tds and then just ask for the text from the first or second one._
# * _**Hint:** If you use BeautifulSoup, you can select elements by attributes other than class or id - instead of `doc.find_all({'class': 'cat'})` you can do things like `doc.find_all({'other_attribute': 'blah'})` (sorry for the awful example)._
# * _**Hint:** If you love `pd.read_html` you might also be interested in `pd.concat` and potentially `list()`. But you'll have to clean a little more!_

# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
response = requests.get('https://rocktumbler.com/blog/rock-and-mineral-clubs/')
doc = BeautifulSoup(response.text)

# %% [markdown]
# ### just alabama info

# %%
alabama_stuff = doc.find_all('section')[1]
alabama_stuff
# Out:
# <section>
# <br/><br/>
# <table bgcolor="#CCCCCC" cellpadding="4" cellspacing="1" width="100%"><tr><td bgcolor="#B9EDB8">
# <h3>Alabama Rock and Mineral Clubs</h3>
# </td></tr></table>
# <table bgcolor="#CCCCCC" border="0" cellpadding="4" cellspacing="1" class="font12" width="100%">
# <tr bgcolor="#FFFFFF"><td width="60%"><a href="http://www.lapidaryclub.com/">Alabama Mineral &amp; Lapidary Society</a></td>
# <td width="40%">Birmingham</td></tr>
# <tr bgcolor="#FFFFFF"><td width="60%"><a href="http://www.wiregrassrockhounds.com/">Dothan Gem &amp; Mineral Club</a></td>
# <td width="40%">Dothan</td></tr>
# <tr bgcolor="#FFFFFF"><td width="60%"><a href="http://huntsvillegms.org/">Huntsville Gem and Mineral Society</a></td>
# <td width="40%">Huntsville</td></tr>
# <tr bgcolor="#FFFFFF"><td width="60%"><a href="http://www.mobilerockandgem.com/">Mobile Rock &amp; Gem Society</a></td>
# <td width="40%">Mobile</td></tr>
# <tr bgcolor="#FFFFFF"><td width="60%"><a href="http://montgomerygemandmineralsociety.com/mgms/">Montgomery Gem &amp; Mineral Society</a></td>
# <td width="40%">Montgomery</td></tr>
# </table>
# </section>

# %%
# club names
alabama_a = alabama_stuff.find_all('a')
for item in alabama_a:
    print(item.text.strip())
# Out:
# Alabama Mineral & Lapidary Society
# Dothan Gem & Mineral Club
# Huntsville Gem and Mineral Society
# Mobile Rock & Gem Society
# Montgomery Gem & Mineral Society

# %%
# cities
alabama_tr = alabama_stuff.find_all('td')
count = 2
for item in alabama_tr[1:]:
    if count % 2:
        name_and_city = item.text.strip()
        print(name_and_city)
    count = count + 1
# Out:
# Birmingham
# Dothan
# Huntsville
# Mobile
# Montgomery

# %%
alabama_tr = alabama_stuff.find_all('tr')
for item in alabama_tr[1:]:
    name = item.find('td').text.strip()
    print(name)    
    city = item.find_all('td')[1].text.strip()
    print(city)
    url = item.find('a')['href']
    print(url)
    state = alabama_stuff.find('h3').text.strip()
    state_finder = r"(.*) Rock and Mineral Clubs"
    state_name = re.findall(state_finder,state)
    for thing in state_name:
        print(thing)
# Out:
# Alabama Mineral & Lapidary Society
# Birmingham
# http://www.lapidaryclub.com/
# Alabama
# Dothan Gem & Mineral Club
# Dothan
# http://www.wiregrassrockhounds.com/
# Alabama
# Huntsville Gem and Mineral Society
# Huntsville
# http://huntsvillegms.org/
# Alabama
# Mobile Rock & Gem Society
# Mobile
# http://www.mobilerockandgem.com/
# Alabama
# Montgomery Gem & Mineral Society
# Montgomery
# http://montgomerygemandmineralsociety.com/mgms/
# Alabama

# %% [markdown]
# ### putting it all together

# %%
stuff = doc.find_all('section')[1:51]

# %%
rock_list = []
for item in stuff:
    trs = item.find_all('tr')
    for thing in trs[1:]:
        name = thing.find_all('td')[0].text.strip()
        city = thing.find_all('td')[1].text.strip()
        url = thing.find('a')['href']
        state = trs[0].find('h3').text.strip()
        state_finder = r"(.*) Rock and Mineral Clubs"
        state_name = re.findall(state_finder,state)
        for thingamabob in state_name:
            thingamabob
        rock_list.append({
            'name': name,
            'city': city,
            'url': url,
            'state': thingamabob
        })

# %%
rock_list
# Out:
# [{'name': 'Alabama Mineral & Lapidary Society',
#   'city': 'Birmingham',
#   'url': 'http://www.lapidaryclub.com/',
#   'state': 'Alabama'},
#  {'name': 'Dothan Gem & Mineral Club',
#   'city': 'Dothan',
#   'url': 'http://www.wiregrassrockhounds.com/',
#   'state': 'Alabama'},
#  {'name': 'Huntsville Gem and Mineral Society',
#   'city': 'Huntsville',
#   'url': 'http://huntsvillegms.org/',
#   'state': 'Alabama'},
#  {'name': 'Mobile Rock & Gem Society',
#   'city': 'Mobile',
#   'url': 'http://www.mobilerockandgem.com/',
#   'state': 'Alabama'},
#  {'name': 'Montgomery Gem & Mineral Society',
#   'city': 'Montgomery',
#   'url': 'http://montgomerygemandmineralsociety.com/mgms/',
#   'state': 'Alabama'},
#  {'name': 'Chugach Gem & Mineral Society',
#   'city': 'Anchorage',
#   'url': 'http://www.chugachgemandmineralsociety.com/',
#   'state': 'Alaska'},
#  {'name': 'Mat-Su Rock and Mineral Club',
#   'city': 'Palmer',
#   'url': 'http://matsurockclub.com/',
#   'state': 'Alaska'},
#  {'name': 'Apache Junction Rock and Gem Club',
#   'city': 'Apache Junction',
#   'url': 'http://www.ajrockclub.com/',
#   'state': 'Arizona'},
#  {'name': 'Black Canyon City Rock Club',
#   'city': 'Black Canyon City',
#   'url': 'http://www.bccrockclub.mysite.com/',
#   'state': 'Arizona'},
#  {'name': 'Daisy Mountain Rock & Mineral Club',
#   'city': 'Anthem',
#   'url': 'http://www.dmrmc.com/',
#   'state': 'Arizona'},
#  {'name': 'Gila County Gem & Mineral Society',
#   'city': 'Miami',
#   'url': 'http://gilagem.org/',
#   'state': 'Arizona'},
#  {'name': 'Huachuca Mineral and Gem Club',
#   'city': 'Sierra Vista',
#   'url': 'http://www.huachucamineralandgemclub.info/',
#   'state': 'Arizona'},
#  {'name': 'Lake Havasu Gem & Mineral Society',
#   'city': 'Lake Havasu City',
#   'url': 'http://www.lakehavasugms.org/',
#   'state': 'Arizona'},
#  {'name': 'Mineralogical Society of Arizona',
#   'city': 'Scottsdale',
#   'url': 'http://www.msaaz.org/',
#   'state': 'Arizona'},
#  {'name': 'Mingus Gem & Mineral Club',
#   'city': 'Cottonwood',
#   'url': 'http://www.mingusclub.org/',
#   'state': 'Arizona'},
#  {'name': 'Mohave County Gemstoners',
#   'city': 'Kingman',
#   'url': 'http://www.gemstoners.org/',
#   'state': 'Arizona'},
#  {'name': 'Old Pueblo Lapidary Club',
#   'city': 'Tucson',
#   'url': 'http://www.lapidaryclub.org/',
#   'state': 'Arizona'},
#  {'name': 'Pinal Gem and Mineral Society',
#   'city': 'Coolidge',
#   'url': 'https://www.pinalgeologymuseum.org/index.php/pinal-gem-mineral-society/about-pgms',
#   'state': 'Arizona'},
#  {'name': 'Prescott Gem & Mineral Club',
#   'city': 'Prescott Valley',
#   'url': 'http://www.prescottgemmineral.org/',
#   'state': 'Arizona'},
#  {'name': 'Quartzsite Roadrunners Gem & Mineral Club',
#   'city': 'Quartzsite',
#   'url': 'http://www.qrgmc.org/',
#   'state': 'Arizona'},
#  {'name': 'Rockhounds West',
#   'city': 'Phoenix',
#   'url': 'http://rockhounds.scwclubs.com/',
#   'state': 'Arizona'},
#  {'name': 'Sedona Gem & Mineral Club',
#   'city': 'Sedona',
#   'url': 'http://www.sedonagemandmineral.org/',
#   'state': 'Arizona'},
#  {'name': 'Silvery Colorado River Rock Club',
#   'city': 'Bullhead City',
#   'url': 'http://scrrc.blogspot.com/',
#   'state': 'Arizona'},
#  {'name': 'Sunsites Gem and Mineral Club',
#   'city': 'Pearce',
#   'url': 'https://sites.google.com/site/cochisecountyrock/',
#   'state': 'Arizona'},
#  {'name': 'Tucson Gem and Mineral Society',
#   'city': 'Tucson',
#   'url': 'http://www.tgms.org/',
#   'state': 'Arizona'},
#  {'name': 'Verde River Rockhounds',
#   'city': 'Cottonwood',
#   'url': 'http://www.verderiverrockhounds.com/',
#   'state': 'Arizona'},
#  {'name': 'West Valley Rock & Mineral Club',
#   'city': 'Buckeye',
#   'url': 'http://www.westvalleyrockandmineralclub.com/',
#   'state': 'Arizona'},
#  {'name': 'White Mountain Gem & Mineral Club',
#   'city': 'Show Low',
#   'url': 'http://whitemountain-azrockclub.org/',
#   'state': 'Arizona'},
#  {'name': 'Wickenburg Gem and Mineral Society',
#   'city': 'Wickenburg',
#   'url': 'http://www.wickenburggms.org/',
#   'state': 'Arizona'},
#  {'name': 'Central Arkansas Gem, Mineral and Geology Society',
#   'city': 'Little Rock',
#   'url': 'http://www.centralarrockhound.org/',
#   'state': 'Arkansas'},
#  {'name': 'Northwest Arkansas Gem & Mineral Society',
#   'city': 'Siloam Springs',
#   'url': 'http://www.nwarockhounds.org/',
#   'state': 'Arkansas'},
#  {'name': 'Ozark Earth Science Gem, Mineral & Fossil Club',
#   'city': 'Mountain Home',
#   'url': 'https://www.ozarkearthscience.com/',
#   'state': 'Arkansas'},
#  {'name': 'Amador County Gem & Mineral Society',
#   'city': 'Sutter Creek',
#   'url': 'http://www.amadorgemandmineral.org/',
#   'state': 'California'},
#  {'name': 'American Opal Society',
#   'city': 'Anaheim',
#   'url': 'http://www.opalsociety.org/',
#   'state': 'California'},
#  {'name': 'Antelope Valley Gem and Mineral Club',
#   'city': 'Lancaster',
#   'url': 'http://avgem.weebly.com/',
#   'state': 'California'},
#  {'name': 'Antioch Lapidary Club',
#   'city': 'Antioch',
#   'url': 'http://www.antiochlapidaryclub.com/',
#   'state': 'California'},
#  {'name': 'Borrego Rock and Gem Club',
#   'city': 'Borrego Springs',
#   'url': 'http://www.abdnha.org/bragclub.html',
#   'state': 'California'},
#  {'name': 'Calaveras Gem & Mineral Society',
#   'city': 'Angels Camp',
#   'url': 'http://www.calaverasgemandmineral.org/',
#   'state': 'California'},
#  {'name': 'Carmel Valley Gem and Mineral Society',
#   'city': 'Pacific Grove',
#   'url': 'http://www.cvgms.rocks/',
#   'state': 'California'},
#  {'name': 'Central Coast Treasure Hunters Association',
#   'city': 'San Luis Obispo',
#   'url': 'http://www.cctha.org/',
#   'state': 'California'},
#  {'name': 'Coalinga Rockhound Society',
#   'city': 'Coalinga',
#   'url': 'https://sites.google.com/site/coalingarockhounds/',
#   'state': 'California'},
#  {'name': 'Conejo Gem & Mineral Club',
#   'city': 'Thousand Oaks',
#   'url': 'http://www.cgamc.org/',
#   'state': 'California'},
#  {'name': 'Contra Costa Mineral & Gem Society',
#   'city': 'Concord',
#   'url': 'http://www.ccmgs.org/',
#   'state': 'California'},
#  {'name': 'The Culver City Rock and Mineral Club',
#   'city': 'Culver City',
#   'url': 'http://culvercityrocks.org/',
#   'state': 'California'},
#  {'name': 'Del Air Rockhounds Club',
#   'city': 'Northridge',
#   'url': 'http://delairrockhounds.blogspot.com/',
#   'state': 'California'},
#  {'name': 'Delvers Gem & Mineral Society',
#   'city': 'Bellflower',
#   'url': 'https://delversgemclub.wordpress.com/',
#   'state': 'California'},
#  {'name': 'El Cajon Valley Gem & Mineral Society',
#   'city': 'El Cajon',
#   'url': 'http://www.ecvgms.org/',
#   'state': 'California'},
#  {'name': 'El Dorado County Mineral and Gem Society',
#   'city': 'Placerville',
#   'url': 'http://www.eldoradomineralandgem.org/',
#   'state': 'California'},
#  {'name': 'Faceters Guild of Southern California',
#   'city': 'Buena Park',
#   'url': 'http://www.fgosc.com/',
#   'state': 'California'},
#  {'name': 'Fallbrook Gem and Mineral Society, Inc.',
#   'city': 'Fallbrook',
#   'url': 'http://www.fgms.org/FGMS/Home.html',
#   'state': 'California'},
#  {'name': 'Feather River Lapidary & Mineral Society',
#   'city': 'Oroville',
#   'url': 'http://www.featherriverrocks.org/',
#   'state': 'California'},
#  {'name': 'First Class Miners',
#   'city': 'Yucca Valley',
#   'url': 'http://www.firstclassminers.org/',
#   'state': 'California'},
#  {'name': 'Fossils for Fun Society, Inc.',
#   'city': 'North Highlands',
#   'url': 'https://www.facebook.com/The-Fossils-for-Fun-Society-994879667246272/',
#   'state': 'California'},
#  {'name': 'Fresno Gem & Mineral Society',
#   'city': 'Fresno',
#   'url': 'http://fgms.us/',
#   'state': 'California'},
#  {'name': 'Gold Country Treasure Seekers',
#   'city': 'Placerville',
#   'url': 'https://goldcountrytreasureseekers.shutterfly.com/',
#   'state': 'California'},
#  {'name': 'Hi-Desert Rockhounds of Morongo Valley',
#   'city': 'Yucca Valley',
#   'url': 'http://www.hi-desertrockhounds.org/',
#   'state': 'California'},
#  {'name': 'Indian Wells Valley Gem & Mineral Society',
#   'city': 'Ridgecrest',
#   'url': 'http://indianwells.weebly.com/',
#   'state': 'California'},
#  {'name': 'Kern County Mineral Society',
#   'city': 'Bakersfield',
#   'url': 'http://kerncountymineralsociety.org/',
#   'state': 'California'},
#  {'name': 'Lemoore Gem and Mineral Club',
#   'city': 'Lemoore',
#   'url': 'https://www.facebook.com/Lemoore-Gem-and-Mineral-Club-706220872829687/',
#   'state': 'California'},
#  {'name': 'Livermore Valley Lithophiles',
#   'city': 'Livermore',
#   'url': 'http://www.lithophiles.com/',
#   'state': 'California'},
#  {'name': 'Line Pine Gem & Mieral Society',
#   'city': 'Lone Pine',
#   'url': 'http://lpgms.org/',
#   'state': 'California'},
#  {'name': 'Mariposa Gem & Mineral Club',
#   'city': 'Mariposa',
#   'url': 'http://mariposagmc.org/',
#   'state': 'California'},
#  {'name': 'Mineral & Gem Society of Castro Valley',
#   'city': 'Hayward',
#   'url': 'http://www.mgscv.org/',
#   'state': 'California'},
#  {'name': 'Mineralogical Society of Southern California',
#   'city': 'Pasadena',
#   'url': 'http://www.mineralsocal.org/',
#   'state': 'California'},
#  {'name': 'Mojave Desert Gem & Mineral Society',
#   'city': 'Barstow',
#   'url': 'http://www.mdgms.net/',
#   'state': 'California'},
#  {'name': 'Monrovia Rock Hounds Inc.',
#   'city': 'Monrovia',
#   'url': 'http://www.moroks.com/',
#   'state': 'California'},
#  {'name': 'Mother Lode Mineral Society',
#   'city': 'Modesto',
#   'url': 'http://www.motherlodemineralsociety.com/',
#   'state': 'California'},
#  {'name': 'Needles Gem & Mineral Club',
#   'city': 'Mohave Valley',
#   'url': 'http://needlesgemmineralclub.blogspot.com/',
#   'state': 'California'},
#  {'name': 'Nevada County Gem & Mineral Society',
#   'city': 'Grass Valley',
#   'url': 'http://www.ncgms.org/',
#   'state': 'California'},
#  {'name': 'Northern California Geological Society',
#   'city': 'Orinda',
#   'url': 'http://www.ncgeolsoc.org/',
#   'state': 'California'},
#  {'name': 'North Orange County Gem & Mineral Society',
#   'city': 'La Habra',
#   'url': 'http://www.nocgms.com/',
#   'state': 'California'},
#  {'name': 'Orange Belt Mineralogical Society',
#   'city': 'San Bernardino',
#   'url': 'http://obmsrocks.yolasite.com/',
#   'state': 'California'},
#  {'name': 'Orcutt Mineral Society',
#   'city': 'Santa Maria',
#   'url': 'http://www.omsinc.org/',
#   'state': 'California'},
#  {'name': 'Oxnard Gem & Mineral Society',
#   'city': 'Oxnard',
#   'url': 'http://oxnardgem.com/home/',
#   'state': 'California'},
#  {'name': 'Palmdale Gem & Mineral Club',
#   'city': 'Palmdale',
#   'url': 'https://www.facebook.com/palmdalegemandmineralclub/',
#   'state': 'California'},
#  {'name': 'Palomar Gem & Mineral Club',
#   'city': 'Escondido',
#   'url': 'http://palomargem.org/',
#   'state': 'California'},
#  {'name': 'Palos Verdes Gem & Mineral Society',
#   'city': 'Rolling Hills Estates',
#   'url': 'http://www.palos-verdes-gem-and-mineral-society.org/',
#   'state': 'California'},
#  {'name': 'Paradise Gem & Mineral Club',
#   'city': 'Paradise',
#   'url': 'http://www.paradisegem.org/',
#   'state': 'California'},
#  {'name': 'Pasadena Lapidary Society',
#   'city': 'Pasadena',
#   'url': 'http://www.pasadenalapidarysociety.org/',
#   'state': 'California'},
#  {'name': 'Peninsula Gem & Geology Society, Inc.',
#   'city': 'Los Altos',
#   'url': 'http://pggs.org/',
#   'state': 'California'},
#  {'name': 'Roseville Rock Rollers',
#   'city': 'Roseville',
#   'url': 'http://www.rockrollers.com/',
#   'state': 'California'},
#  {'name': 'Route 66 Gold Miners Inc',
#   'city': 'Brea',
#   'url': 'http://www.route66goldminers.org/',
#   'state': 'California'},
#  {'name': 'Sacramento Mineral Society',
#   'city': 'Sacramento',
#   'url': 'http://www.sacramentomineralsociety.org/',
#   'state': 'California'},
#  {'name': 'Sacramento Valley Detecting Buffs',
#   'city': 'North Highlands',
#   'url': 'http://www.sacramentovalleydetectingbuffs.com/',
#   'state': 'California'},
#  {'name': 'Salinas Valley Rock and Gem Club',
#   'city': 'Salinas',
#   'url': 'https://salinasrockandgem.pagecloud.com/',
#   'state': 'California'},
#  {'name': 'San Diego Gem and Mineral Society',
#   'city': 'San Diego',
#   'url': 'http://www.sdmg.org/',
#   'state': 'California'},
#  {'name': 'San Diego Lapidary Society',
#   'city': 'San Diego',
#   'url': 'http://sandiegolapidarysociety.org/',
#   'state': 'California'},
#  {'name': 'San Francisco Gem and Mineral Society, Inc.',
#   'city': 'San Francisco',
#   'url': 'http://www.sfgms.org/',
#   'state': 'California'},
#  {'name': 'San Joaquin Valley Lapidary Society',
#   'city': 'Bakersfield',
#   'url': 'http://sjvls.blogspot.com/',
#   'state': 'California'},
#  {'name': 'San Luis Obispo Gem & Mineral Club',
#   'city': 'San Luis Obispo',
#   'url': 'http://www.slogem.org/',
#   'state': 'California'},
#  {'name': 'Santa Ana Rock & Mineral Club, Inc.',
#   'city': 'Santa Ana',
#   'url': 'http://www.sarmclub.org/',
#   'state': 'California'},
#  {'name': 'Santa Clara Valley Gem & Mineral Society',
#   'city': 'San Jose',
#   'url': 'http://www.scvgms.org/',
#   'state': 'California'},
#  {'name': 'Santa Cruz Mineral and Gem Society',
#   'city': 'Santa Cruz',
#   'url': 'https://www.facebook.com/scmgs/',
#   'state': 'California'},
#  {'name': 'Santa Lucia Rockhounds',
#   'city': 'Paso Robles',
#   'url': 'http://www.slrockhounds.org/',
#   'state': 'California'},
#  {'name': 'Santa Rosa Mineral And Gem Society, Inc.',
#   'city': 'Santa Rosa',
#   'url': 'http://www.srmgs.org/',
#   'state': 'California'},
#  {'name': 'Searchers Gem and Mineral Society',
#   'city': 'Anaheim',
#   'url': 'https://www.searchersrocks.org/',
#   'state': 'California'},
#  {'name': 'Searles Lake Gem and Mineral Society, Inc.',
#   'city': 'Trona',
#   'url': 'http://www1.iwvisp.com/tronagemclub/',
#   'state': 'California'},
#  {'name': 'Sequoia Gem and Mineral Society',
#   'city': 'Redwood City',
#   'url': 'http://www.sequoiagemandmineralsociety.org/',
#   'state': 'California'},
#  {'name': 'Shadow Mountain Gem & Mineral Society',
#   'city': 'Palm Springs',
#   'url': 'http://www.shadowmountaingemmineral.org/',
#   'state': 'California'},
#  {'name': 'Shasta Gem & Mineral Society',
#   'city': 'Redding',
#   'url': 'http://www.shastagemandmineral.com/',
#   'state': 'California'},
#  {'name': 'Sierra Pelona Rock Club',
#   'city': 'Newhall',
#   'url': 'http://www.sierrapelona.com/',
#   'state': 'California'},
#  {'name': 'South Bay Lapidary & Mineral Society',
#   'city': 'Torrance',
#   'url': 'https://southbaylapidaryandmineralsociety.com/',
#   'state': 'California'},
#  {'name': 'South Orange County Gem & Mineral Society',
#   'city': 'San Clemente',
#   'url': 'https://www.facebook.com/South-Orange-County-Gem-Mineral-Society-255366124502612/',
#   'state': 'California'},
#  {'name': 'Southern California Paleontological Society',
#   'city': 'Los Angeles',
#   'url': 'http://socalpaleo.com/',
#   'state': 'California'},
#  {'name': 'Stockton Lapidary & Mineral Club',
#   'city': 'Stockton',
#   'url': 'http://www.stocktonlapidary.com/',
#   'state': 'California'},
#  {'name': 'Sutter Buttes Gem & Mineral Society',
#   'city': 'Marysville',
#   'url': 'https://sutterbuttesgemmin.org/',
#   'state': 'California'},
#  {'name': 'Tehachapi Valley Gem & Mineral Society',
#   'city': 'Tehachapi',
#   'url': 'http://www.tvgms.org/',
#   'state': 'California'},
#  {'name': 'Tule Gem and Mineral Society',
#   'city': 'Farmersville',
#   'url': 'http://www.tulegem.com/',
#   'state': 'California'},
#  {'name': 'Vallejo Gem & Mineral Society',
#   'city': 'Vallejo',
#   'url': 'http://www.vjgems.org/',
#   'state': 'California'},
#  {'name': 'Valley Prospectors, Inc.',
#   'city': 'San Bernardino',
#   'url': 'https://www.valleyprospectors.com/',
#   'state': 'California'},
#  {'name': 'Ventura Gem & Mineral Society, Inc',
#   'city': 'Ventura',
#   'url': 'http://vgms.org/',
#   'state': 'California'},
#  {'name': 'Victor Valley Gem and Mineral Club',
#   'city': 'Victorville',
#   'url': 'http://www.vvgmc.org/',
#   'state': 'California'},
#  {'name': 'Vista Gem & Mineral Society',
#   'city': 'Vista',
#   'url': 'http://www.vistarocks.org/',
#   'state': 'California'},
#  {'name': 'West Coast Prospectors & Treasure Hunters Association',
#   'city': 'Garden Grove',
#   'url': 'http://westcoasters.org/',
#   'state': 'California'},
#  {'name': 'West End Prospectors Corporation',
#   'city': 'Norco',
#   'url': 'http://www.wepcgold.com',
#   'state': 'California'},
#  {'name': 'Whittier Gem and Mineral Society, Inc.',
#   'city': 'Whittier',
#   'url': 'http://wgmsca.com/index.html',
#   'state': 'California'},
#  {'name': 'Woodland Hills Rock Chippers, Inc.',
#   'city': 'San Fernando Valley',
#   'url': 'http://www.rockchippers.org/',
#   'state': 'California'},
#  {'name': 'Yucaipa Valley Gem & Mineral Society',
#   'city': 'Yucaipa',
#   'url': 'http://www.yvgms.org/wiki/',
#   'state': 'California'},
#  {'name': 'Canon City Geology Club',
#   'city': 'Canon City',
#   'url': 'http://www.canoncitygeologyclub.com/',
#   'state': 'Colorado'},
#  {'name': 'Colorado Gold Camp',
#   'city': 'Frisco',
#   'url': 'http://coloradogoldcamp.com/',
#   'state': 'Colorado'},
#  {'name': 'Colorado Mineral Society',
#   'city': 'Lakewood',
#   'url': 'http://www.coloradomineralsociety.org/',
#   'state': 'Colorado'},
#  {'name': 'Colorado Prospector',
#   'city': 'Alamosa',
#   'url': 'http://www.coloradoprospector.com/',
#   'state': 'Colorado'},
#  {'name': 'Colorado Springs Mineral Society',
#   'city': 'Colorado Springs',
#   'url': 'http://www.csms1936.com/',
#   'state': 'Colorado'},
#  {'name': 'Columbine Gem and Mineral Society',
#   'city': 'Salida',
#   'url': 'http://rockaholics.org/',
#   'state': 'Colorado'},
#  {'name': 'Denver Gem and Mineral Guild',
#   'city': 'Denver',
#   'url': 'http://denvergem.org/index.html',
#   'state': 'Colorado'},
#  {'name': 'Flatirons Mineral Club',
#   'city': 'Boulder',
#   'url': 'http://flatironsmineralclub.org/',
#   'state': 'Colorado'},
#  {'name': 'Fort Collins Rockhounds',
#   'city': 'Fort Collins',
#   'url': 'http://www.fortcollinsrockhounds.org/',
#   'state': 'Colorado'},
#  {'name': 'Four Corners Gem & Mineral Club',
#   'city': 'Durango',
#   'url': 'http://www.durangorocks.org/',
#   'state': 'Colorado'},
#  {'name': 'Friends of Mineralogy - Colorado Chapter',
#   'city': 'Denver',
#   'url': 'http://friendsofmineralogycolorado.org/',
#   'state': 'Colorado'},
#  {'name': 'Grand Junction Gem & Mineral Club',
#   'city': 'Grand Junction',
#   'url': 'http://www.grandjunctionrockclub.org/',
#   'state': 'Colorado'},
#  {'name': 'Lake George Gem & Mineral club',
#   'city': 'Lake George',
#   'url': 'http://www.lggmclub.org/',
#   'state': 'Colorado'},
#  {'name': 'Littleton Gem and Mineral Club, Inc.',
#   'city': 'Littleton',
#   'url': 'http://littletongemandmineralclub.com/',
#   'state': 'Colorado'},
#  {'name': 'Mile High Rock and Mineral Society',
#   'city': 'Arvada',
#   'url': 'http://www.milehirams.com/',
#   'state': 'Colorado'},
#  {'name': 'North Jeffco Gem & Mineral Club',
#   'city': 'Arvada',
#   'url': 'http://www.peaktopeak.com/njeffco/index.php',
#   'state': 'Colorado'},
#  {'name': 'Pueblo Rockhounds',
#   'city': 'Pueblo',
#   'url': 'http://www.pueblorockhounds.org/',
#   'state': 'Colorado'},
#  {'name': 'Western Interior Paleontological Society',
#   'city': 'Denver',
#   'url': 'http://www.westernpaleo.org/',
#   'state': 'Colorado'},
#  {'name': 'Bristol Gem & Mineral Club',
#   'city': 'Bristol',
#   'url': 'http://bristolgem.org/',
#   'state': 'Connecticut'},
#  {'name': 'Danbury Mineralogical Society',
#   'city': 'Danbury',
#   'url': 'http://danburymineralogicalsociety.weebly.com/',
#   'state': 'Connecticut'},
#  {'name': 'Lapidary and Mineral Society of Central Connecticut',
#   'city': 'Meriden',
#   'url': 'http://www.lmscc.org/',
#   'state': 'Connecticut'},
#  {'name': 'New Haven Mineral Club',
#   'city': 'New Haven',
#   'url': 'http://www.newhavenmineralclub.org/',
#   'state': 'Connecticut'},
#  {'name': 'Stamford Mineralogical Society',
#   'city': 'Stamford',
#   'url': 'http://www.stamfordmineralsociety.org/',
#   'state': 'Connecticut'},
#  {'name': 'Delaware Mineralogical Society, Inc.',
#   'city': 'Wilmington',
#   'url': 'http://www.delminsociety.net/',
#   'state': 'Delaware'},
#  {'name': 'Canaveral Mineral & Gem Society',
#   'city': 'Melbourne',
#   'url': 'http://www.canaveral-mgs.com/',
#   'state': 'Florida'},
#  {'name': 'Central Brevard Rock and Gem Club',
#   'city': 'Merritt Island',
#   'url': 'http://www.centralbrevardgems.org/',
#   'state': 'Florida'},
#  {'name': 'Central Florida Mineral and Gem Society',
#   'city': 'Winter Park',
#   'url': 'http://www.cfmgs.org/',
#   'state': 'Florida'},
#  {'name': 'Florida Fossil Hunters',
#   'city': 'Orlando',
#   'url': 'http://floridafossilhunters.com/',
#   'state': 'Florida'},
#  {'name': 'Florida Gold Coast Gem & Mineral Society',
#   'city': 'Hollywood',
#   'url': 'http://fgcgms.com/main/',
#   'state': 'Florida'},
#  {'name': 'Fossil Club of Lee County',
#   'city': 'Ft. Myers',
#   'url': 'http://www.fcolc.com/',
#   'state': 'Florida'},
#  {'name': 'Gainesville Gem & Mineral Society',
#   'city': 'Gainesville',
#   'url': 'http://gainesvillegms.weebly.com/',
#   'state': 'Florida'},
#  {'name': 'Gem and Mineral Society of the Palm Beaches',
#   'city': 'West Palm Beach',
#   'url': 'http://www.gemandmineralsociety.org/',
#   'state': 'Florida'},
#  {'name': 'Imperial Bone Valley Gem, Mineral, & Fossil Society',
#   'city': 'Lakeland',
#   'url': 'http://www.bonevalley.net/',
#   'state': 'Florida'},
#  {'name': 'Jacksonville Gem and Mineral Society, Inc.',
#   'city': 'Jacksonville',
#   'url': 'http://www.jaxgemandmineral.org/',
#   'state': 'Florida'},
#  {'name': 'Miami Mineralogical and Lapidary Guild, Inc.',
#   'city': 'Miami',
#   'url': 'http://www.mmlg-inc.org/',
#   'state': 'Florida'},
#  {'name': 'Playground Gem and Mineral Society',
#   'city': 'Ft. Walton Beach',
#   'url': 'http://playgroundgem.org/',
#   'state': 'Florida'},
#  {'name': 'Southwest Florida Fossil Society',
#   'city': 'Punta Gorda',
#   'url': 'http://www.southwestfloridafossilsociety.org/',
#   'state': 'Florida'},
#  {'name': 'St Lucie County Rock and Gem Club',
#   'city': 'Port St Lucie',
#   'url': 'http://www.slcrockandgem.org/',
#   'state': 'Florida'},
#  {'name': 'Suncoast Gem and Mineral Society',
#   'city': 'St Petersburg',
#   'url': 'http://sgams.com/',
#   'state': 'Florida'},
#  {'name': 'Tampa Bay Fossil Club',
#   'city': 'Palm Harbor',
#   'url': 'http://www.tampabayfossilclub.com/',
#   'state': 'Florida'},
#  {'name': 'Tampa Bay Mineral & Science Club, Inc.',
#   'city': 'Tampa',
#   'url': 'http://www.tampabayrockclub.com/',
#   'state': 'Florida'},
#  {'name': 'The Villages Gem and Mineral Society',
#   'city': 'The Villages',
#   'url': 'http://www.thevillagesgemandmineralsociety.com/',
#   'state': 'Florida'},
#  {'name': 'Tomoka Faceters Guild',
#   'city': 'Palm Coast',
#   'url': 'http://www.tomokafacetersguild.org/index.html',
#   'state': 'Florida'},
#  {'name': 'Withlacoochee Rockhounds',
#   'city': 'Spring Hill',
#   'url': 'http://www.withlacoocheerockhounds.com/',
#   'state': 'Florida'},
#  {'name': 'Athens Rock and Gem Club',
#   'city': 'Athens',
#   'url': 'http://www.athensrockandgemclub.org/',
#   'state': 'Georgia'},
#  {'name': 'Augusta Gem & Mineral Society',
#   'city': 'Augusta',
#   'url': 'http://agams.club/',
#   'state': 'Georgia'},
#  {'name': 'Cobb County Gem and Mineral Society',
#   'city': 'Marietta',
#   'url': 'https://www.ccgms.org/',
#   'state': 'Georgia'},
#  {'name': 'Georgia Mineral Society, Inc.',
#   'city': 'Norcross',
#   'url': 'http://www.gamineral.org/',
#   'state': 'Georgia'},
#  {'name': 'Mid-Georgia Gem and Mineral Society',
#   'city': 'Macon',
#   'url': 'http://midgagmsorg.ipage.com/',
#   'state': 'Georgia'},
#  {'name': 'Rome Georgia Mineral Society Inc.',
#   'city': 'Rome',
#   'url': 'https://rogams.wordpress.com/',
#   'state': 'Georgia'},
#  {'name': "Hui Pohaku 'O Hawai'i Rock & Mineral Society of Hawai'i, Inc.",
#   'city': 'Honolulu',
#   'url': 'http://pohakugalore.net/Hui_pohaku/Hiu_pohaku_1.html',
#   'state': 'Hawaii'},
#  {'name': 'Hells Canyon Gem Club, Inc.',
#   'city': 'Lewiston',
#   'url': 'http://www.hellscanyongemclub.com/',
#   'state': 'Idaho'},
#  {'name': 'Idaho Falls Gem & Mineral Society',
#   'city': 'Idaho Falls',
#   'url': 'http://ifgemmineral.weebly.com/',
#   'state': 'Idaho'},
#  {'name': 'Idaho Gem Club, Inc.',
#   'city': 'Boise',
#   'url': 'http://www.idahogemclub.com/',
#   'state': 'Idaho'},
#  {'name': 'Magic Valley Gem Club',
#   'city': 'Twin Falls',
#   'url': 'http://magicvalleygemclub.org/',
#   'state': 'Idaho'},
#  {'name': 'North Idaho Mineral Club',
#   'city': "Coeur d'Alene",
#   'url': 'http://www.northidahomineralclub.com/',
#   'state': 'Idaho'},
#  {'name': 'Owyhee Gem & Mineral Society',
#   'city': 'Caldwell',
#   'url': 'http://www.owyheerocks.com/',
#   'state': 'Idaho'},
#  {'name': 'Pend Oreille Rock and Gem Club',
#   'city': 'Oldtown',
#   'url': 'https://pendoreillerockandgemclub.wordpress.com/',
#   'state': 'Idaho'},
#  {'name': 'Southeast Idaho Gem and Mineral Society',
#   'city': 'Boise',
#   'url': 'https://www.facebook.com/SEIGMS',
#   'state': 'Idaho'},
#  {'name': 'Black Hawk Gem & Mineral Club',
#   'city': 'Rock Island',
#   'url': 'http://www.blackhawkgemandmineralclub.com/',
#   'state': 'Illinois'},
#  {'name': 'Central Illinois Gem & Mineral Club',
#   'city': 'Decatur',
#   'url': 'http://rmkapta.wixsite.com/cigmc',
#   'state': 'Illinois'},
#  {'name': 'Chicago Rocks & Minerals Society',
#   'city': 'Skokie',
#   'url': 'http://www.chicagorocks.org/',
#   'state': 'Illinois'},
#  {'name': 'Elgin Rock Club',
#   'city': 'Elgin',
#   'url': 'http://elginrockclub.org/',
#   'state': 'Illinois'},
#  {'name': 'Geodeland Earth Science Clubs, Inc.',
#   'city': 'Macomb',
#   'url': 'http://www.geodeland.com/',
#   'state': 'Illinois'},
#  {'name': 'Lincoln Orbit Earth Science Society',
#   'city': 'Springfield',
#   'url': 'http://www.loess.org/',
#   'state': 'Illinois'},
#  {'name': 'Midwest Historical Research Society',
#   'city': 'Chicago',
#   'url': 'http://www.mhrsusa.com/',
#   'state': 'Illinois'},
#  {'name': 'Northwest Illinois Rock Club',
#   'city': 'Freeport',
#   'url': 'http://nwilrockclubfrpt.blogspot.com/',
#   'state': 'Illinois'},
#  {'name': 'Peoria Academy of Science Geology Section',
#   'city': 'Peoria',
#   'url': 'http://www.pasgeology.com/',
#   'state': 'Illinois'},
#  {'name': 'Southern Illinois Earth Science Club',
#   'city': 'Benton',
#   'url': 'http://www.siesclub.org/',
#   'state': 'Illinois'},
#  {'name': 'West Central Illinois Rock & Mineral Club',
#   'city': 'Macomb',
#   'url': 'http://www.rockchatter.com/',
#   'state': 'Illinois'},
#  {'name': 'West Suburban Lapidary Club',
#   'city': 'Elmhurst',
#   'url': 'http://www.westsuburbanlapidaryclub.com/',
#   'state': 'Illinois'},
#  {'name': '500 Earth Sciences Club',
#   'city': 'Indianapolis',
#   'url': 'http://www.500earthsciencesclub.org/',
#   'state': 'Indiana'},
#  {'name': 'Brown County Rock and Mineral Club',
#   'city': 'Nashville',
#   'url': 'http://browncountyrock.webs.com/',
#   'state': 'Indiana'},
#  {'name': 'Calumet Gem & Mineral Society',
#   'city': 'Crown Point',
#   'url': 'https://www.facebook.com/calumetrockclub',
#   'state': 'Indiana'},
#  {'name': 'Evansville Lapidary Society',
#   'city': 'Evansville',
#   'url': 'http://evansvillelapidarysociety.tumblr.com/',
#   'state': 'Indiana'},
#  {'name': 'Eastern Indiana Gem & Geological Society, Inc.',
#   'city': 'Richmond',
#   'url': 'http://eiggs.weebly.com/',
#   'state': 'Indiana'},
#  {'name': 'Lawrence County Rock Club, Inc',
#   'city': 'Bedford',
#   'url': 'http://www.lawrencecountyrockclub.org/',
#   'state': 'Indiana'},
#  {'name': 'Michiana Gem & Mineral Society, Inc.',
#   'city': 'South Bend',
#   'url': 'http://www.michianagms.org/',
#   'state': 'Indiana'},
#  {'name': 'Three Rivers Gem & Mineral Society',
#   'city': 'Fort Wayne',
#   'url': 'http://3riversgem_mineral.tripod.com/',
#   'state': 'Indiana'},
#  {'name': 'Cedar Valley Rocks and Minerals Society',
#   'city': 'Cedar Rapids',
#   'url': 'http://www.cedarvalleyrockclub.org/',
#   'state': 'Iowa'},
#  {'name': 'Des Moines Lapidary Society',
#   'city': 'Des Moines',
#   'url': 'http://dmlapidary.org/',
#   'state': 'Iowa'},
#  {'name': 'Geology Club @ Cornell College',
#   'city': 'Mount Vernon',
#   'url': 'http://orgs.cornellcollege.edu/geo_club/',
#   'state': 'Iowa'},
#  {'name': 'Iowa State University Geology Club',
#   'city': 'Ames',
#   'url': 'https://www.facebook.com/ISUGEOCLUB/',
#   'state': 'Iowa'},
#  {'name': 'River Valley Rockhounds',
#   'city': 'Fort Dodge',
#   'url': 'http://amfed.org/mwf/states/Iowa/RiverValley.html',
#   'state': 'Iowa'},
#  {'name': 'The Sac & Fox Lapidary Club',
#   'city': 'Fairfield',
#   'url': 'http://members.iowatelecom.net/billrath/rock_club.html',
#   'state': 'Iowa'},
#  {'name': 'McPherson Gem and Mineral Club',
#   'city': 'McPherson',
#   'url': 'https://mcphersongemandmineralclub.org/',
#   'state': 'Kansas'},
#  {'name': 'Olathe Gem and Mineral Society',
#   'city': 'Kansas City',
#   'url': 'http://olathegemclub.com/',
#   'state': 'Kansas'},
#  {'name': 'Topeka Gem & Mineral Society',
#   'city': 'Topeka',
#   'url': 'http://www.topekagms.org/',
#   'state': 'Kansas'},
#  {'name': 'Wichita Gem and Mineral Society',
#   'city': 'Wichita',
#   'url': 'http://www.wgmsks.org/',
#   'state': 'Kansas'},
#  {'name': 'Wichita Paleontological Society',
#   'city': 'Wichita',
#   'url': 'http://www.reocities.com/CapeCanaveral/Hangar/4265/home.html',
#   'state': 'Kansas'},
#  {'name': 'Blue Grass Gem & Mineral Club of Central Kentucky',
#   'city': 'Lexington',
#   'url': 'http://bggamc.homestead.com/',
#   'state': 'Kentucky'},
#  {'name': 'KYANA Geological Society',
#   'city': 'Louisville',
#   'url': 'http://www.kyanageo.org/',
#   'state': 'Kentucky'},
#  {'name': 'Kentucky Paleontological Society',
#   'city': 'Lexington',
#   'url': 'http://www.uky.edu/OtherOrgs/KPS/',
#   'state': 'Kentucky'},
#  {'name': 'Ark-La-Tex Gem & Mineral Society',
#   'city': 'Shreveport',
#   'url': 'http://larockclub.com/',
#   'state': 'Louisiana'},
#  {'name': 'Baton Rouge Gem & Mineral Society',
#   'city': 'Baton Rouge',
#   'url': 'http://www.brgemandmineral.org/',
#   'state': 'Louisiana'},
#  {'name': 'DeRidder Gem & Mineral Society',
#   'city': 'Leesville',
#   'url': 'https://www.facebook.com/DeRidder-Gem-Mineral-Society-1123146734440993/',
#   'state': 'Louisiana'},
#  {'name': 'Kennebec Rocks and Minerals Club',
#   'city': 'Winthrop',
#   'url': 'http://kennebec-rocksandminerals.com/',
#   'state': 'Maine'},
#  {'name': 'Maine Mineralogical & Geological Society',
#   'city': 'Portland',
#   'url': 'http://mainemineralclub.org/',
#   'state': 'Maine'},
#  {'name': 'Oxford County Mineral and Gem Association',
#   'city': 'South Paris',
#   'url': 'http://ocmgassoc.blogspot.com/',
#   'state': 'Maine'},
#  {'name': 'Penobscot Mineral and Lapidary Club',
#   'city': 'Milford',
#   'url': 'http://penobscotminerallapidaryclub.com/index.html',
#   'state': 'Maine'},
#  {'name': 'American Fossil Federation',
#   'city': 'Bowie',
#   'url': 'http://americanfossilfederation.org/Home.html',
#   'state': 'Maryland'},
#  {'name': 'Baltimore Mineral Society',
#   'city': 'Baltimore',
#   'url': 'http://www.baltimoremineralsociety.org/',
#   'state': 'Maryland'},
#  {'name': 'Calvert Marine Museum Fossil Club',
#   'city': 'Solomons',
#   'url': 'http://www.calvertmarinemuseum.com/209/Fossil-Club',
#   'state': 'Maryland'},
#  {'name': 'Central Maryland Rock and Mineral Collectors Exchange',
#   'city': 'Elkridge',
#   'url': 'https://www.meetup.com/rockhounds/',
#   'state': 'Maryland'},
#  {'name': 'Chesapeake Gem & Mineral Society',
#   'city': 'Baltimore',
#   'url': 'http://www.chesapeakegemandmineral.org/',
#   'state': 'Maryland'},
#  {'name': 'Gem Cutters Guild of Baltimore, Inc.',
#   'city': 'Baltimore',
#   'url': 'http://www.gemcuttersguild.com/',
#   'state': 'Maryland'},
#  {'name': 'Gem, Lapidary, and Mineral Society of Montgomery County, MD., Inc.',
#   'city': 'Rockville',
#   'url': 'http://www.glmsmc.com/',
#   'state': 'Maryland'},
#  {'name': 'Maryland Geological Society',
#   'city': 'Bowie',
#   'url': 'http://www.ecphora.net/mgs/',
#   'state': 'Maryland'},
#  {'name': 'Micromineralogists of the National Capital Area',
#   'city': 'Washington, DC',
#   'url': 'http://dcmicrominerals.org/',
#   'state': 'Maryland'},
#  {'name': 'Patuxent Lapidary Guild',
#   'city': 'Annapolis',
#   'url': 'http://www.patuxentlapidary.org/',
#   'state': 'Maryland'},
#  {'name': 'Southern Maryland Rock and Mineral Club',
#   'city': 'Clinton',
#   'url': 'http://www.smrmc.org/',
#   'state': 'Maryland'},
#  {'name': 'The Mineralogical Society of the District of Columbia',
#   'city': 'Washington, DC',
#   'url': 'http://www.mineralogicalsocietyofdc.org/',
#   'state': 'Maryland'},
#  {'name': 'Boston Mineral Club, Inc.',
#   'city': 'Boston',
#   'url': 'http://www.bostonmineralclub.org/',
#   'state': 'Massachusetts'},
#  {'name': 'Connecticut Valley Mineral Club',
#   'city': 'Springfield',
#   'url': 'http://www.cvmineralclub.org/',
#   'state': 'Massachusetts'},
#  {'name': 'Micromounters of New England',
#   'city': 'Chemlsford',
#   'url': 'http://micromountersofnewengland.org/',
#   'state': 'Massachusetts'},
#  {'name': 'Nashoba Valley Mineralogical Society',
#   'city': 'Westford',
#   'url': 'http://www.americantowns.com/ma/westford/organization/nashoba_valley_mineralogical_society',
#   'state': 'Massachusetts'},
#  {'name': 'North Shore Rock & Mineral Club of Massachusetts',
#   'city': 'South Hamilton',
#   'url': 'http://www.northshorerock.org/',
#   'state': 'Massachusetts'},
#  {'name': 'Northern Berkshire Mineral Club',
#   'city': 'North Adams',
#   'url': 'http://nbmclub.webs.com/',
#   'state': 'Massachusetts'},
#  {'name': 'Southeastern Massachusetts Mineral Club',
#   'city': 'Bridgewater',
#   'url': 'http://semmc.com/',
#   'state': 'Massachusetts'},
#  {'name': 'Worcester Mineral Club',
#   'city': 'Worcester',
#   'url': 'http://worcestermineralclub.org/',
#   'state': 'Massachusetts'},
#  {'name': 'Big Rapids Rock, Gem & Mineral Club',
#   'city': 'Big Rapids',
#   'url': 'https://sites.google.com/site/bigrapidsrockgemmineralclub/',
#   'state': 'Michigan'},
#  {'name': 'Central Michigan Lapidary and Mineral Society',
#   'city': 'Lansing',
#   'url': 'http://michrocks.org/',
#   'state': 'Michigan'},
#  {'name': 'Copper Country Rock and Mineral Club',
#   'city': 'Dollar Bay',
#   'url': 'http://www.ccrmc.info/',
#   'state': 'Michigan'},
#  {'name': 'Flint Rock and Gem Club',
#   'city': 'Flint',
#   'url': 'http://www.flintrockandgem.org/',
#   'state': 'Michigan'},
#  {'name': 'Grand Traverse Area Rock and Mineral Club',
#   'city': 'Traverse City',
#   'url': 'http://tcrockhounds.com/',
#   'state': 'Michigan'},
#  {'name': 'Indian Mounds Rock & Mineral Club',
#   'city': 'Wyoming',
#   'url': 'http://www.indianmoundsrockclub.com/',
#   'state': 'Michigan'},
#  {'name': 'Ishpeming Rock and Mineral Club',
#   'city': 'Ishpeming',
#   'url': 'http://www.ishpemingrocks.org/',
#   'state': 'Michigan'},
#  {'name': 'Kalamazoo Geological & Mineral Society',
#   'city': 'Kalamazoo',
#   'url': 'http://kalamazoorockclub.org/',
#   'state': 'Michigan'},
#  {'name': 'Livingston Gem & Mineral Society',
#   'city': 'Howell',
#   'url': 'http://www.livingstongemandmineralsociety.com/',
#   'state': 'Michigan'},
#  {'name': 'Michigan Gem & Mineral Society',
#   'city': 'Michigan Center',
#   'url': 'http://mgmsrockclub.com/',
#   'state': 'Michigan'},
#  {'name': 'Michigan Mineralogical Society',
#   'city': 'Bloomfield Hills',
#   'url': 'https://www.michmin.org/',
#   'state': 'Michigan'},
#  {'name': 'Mid-Michigan Rock Club',
#   'city': 'Midland',
#   'url': 'http://www.midmichrockclub.com/?Page=1',
#   'state': 'Michigan'},
#  {'name': "Midwest Faceters' Guild",
#   'city': 'Grand Rapids',
#   'url': 'http://www.midwestfaceters.org/',
#   'state': 'Michigan'},
#  {'name': 'Midwest Mineralological & Lapidary Society',
#   'city': 'Taylor',
#   'url': 'http://www.mmls.us/',
#   'state': 'Michigan'},
#  {'name': 'Mikenauk Rock and Gem Club',
#   'city': 'Roscommon',
#   'url': 'http://mikenaukclub.weebly.com/',
#   'state': 'Michigan'},
#  {'name': 'Mount Clemens Gem & Lapidary Society',
#   'city': 'Mt. Clemens',
#   'url': 'http://mcgls.org/',
#   'state': 'Michigan'},
#  {'name': 'Oakland County Earth Science Club',
#   'city': 'Waterford',
#   'url': 'http://www.ocesc.com/',
#   'state': 'Michigan'},
#  {'name': 'Roamin Club',
#   'city': 'Livonia',
#   'url': 'https://roaminrockclub.weebly.com/',
#   'state': 'Michigan'},
#  {'name': 'StateLine Gem & Mineral Society',
#   'city': 'Morenci',
#   'url': 'http://statelinegms.com/',
#   'state': 'Michigan'},
#  {'name': 'Tulip City Gem & Mineral Club, Inc.',
#   'city': 'Holland',
#   'url': 'http://www.tulipcity.org/',
#   'state': 'Michigan'},
#  {'name': 'Anoka County Gem & Mineral Club',
#   'city': 'Minneapolis',
#   'url': 'http://www.amfed.org/mwf/states/Minnesota/AnokaGem.html',
#   'state': 'Minnesota'},
#  {'name': 'Cuyuna Rock, Gem and Mineral Society',
#   'city': 'Brainerd',
#   'url': 'http://cuyunarockclub.org/wp/',
#   'state': 'Minnesota'},
#  {'name': 'Minnesota Mineral Club',
#   'city': 'Falcon Heights',
#   'url': 'http://minnesotamineralclub.org/',
#   'state': 'Minnesota'},
#  {'name': 'Minnesota Valley Gem & Mineral Club',
#   'city': 'Mankato',
#   'url': 'http://www.mnvalleygemandmineralclub.com/',
#   'state': 'Minnesota'},
#  {'name': 'St Croix Rockhounds',
#   'city': 'Stillwater',
#   'url': 'http://stcroixrockhounds.org/',
#   'state': 'Minnesota'},
#  {'name': 'Harrison County Gem & Mineral Society, Inc.',
#   'city': 'Gulfport',
#   'url': 'http://www.gulfportgems.org/',
#   'state': 'Mississippi'},
#  {'name': 'Mississippi Gem & Mineral Society',
#   'city': 'Jackson',
#   'url': 'http://missgems.org/',
#   'state': 'Mississippi'},
#  {'name': 'Mississippi Geological Society',
#   'city': 'Jackson',
#   'url': 'http://www.missgeo.com/',
#   'state': 'Mississippi'},
#  {'name': 'Mississippi Gulf Coast Gem and Mineral Society',
#   'city': 'Ocean Springs',
#   'url': 'http://www.mgcgms.org/',
#   'state': 'Mississippi'},
#  {'name': 'North Mississippi Gem and Mineral Society',
#   'city': 'Tupelo',
#   'url': 'http://www.nmgms.org/',
#   'state': 'Mississippi'},
#  {'name': 'Central Missouri Rock and Lapidary Club',
#   'city': 'Columbia',
#   'url': 'http://www.cmrlc.org/',
#   'state': 'Missouri'},
#  {'name': 'Independence Gem & Mineral Society',
#   'city': 'Independence',
#   'url': 'http://www.igams.co/',
#   'state': 'Missouri'},
#  {'name': 'Missouri Valley Gem & Mineral Society',
#   'city': 'St. Joseph',
#   'url': 'http://www.movalleyrockclub.com/',
#   'state': 'Missouri'},
#  {'name': 'Mozarkite Society of Lincoln, Inc.',
#   'city': 'Lincoln',
#   'url': 'http://www.mozarkite.com/',
#   'state': 'Missouri'},
#  {'name': 'Ozark Mountain Gem & Mineral Society',
#   'city': 'Springfield',
#   'url': 'https://www.facebook.com/omgms.57',
#   'state': 'Missouri'},
#  {'name': 'Rock Hobby Club of Greater Saint Louis',
#   'city': 'St. Louis',
#   'url': 'xxxxxhttp://rockhobby.stlearthsci.org/Home.aspxxxxxx',
#   'state': 'Missouri'},
#  {'name': 'Rockwood Gem & Mineral Society',
#   'city': 'St. Louis',
#   'url': 'http://rockwood.stlearthsci.org/',
#   'state': 'Missouri'},
#  {'name': 'St. Louis Mineral & Gem Society',
#   'city': 'St. Louis',
#   'url': 'http://www.stlrockclub.com/',
#   'state': 'Missouri'},
#  {'name': 'Show Me Gems & Minerals Club, Inc.',
#   'city': 'St. Peters',
#   'url': 'http://showme.stlearthsci.org/',
#   'state': 'Missouri'},
#  {'name': 'Show-Me Rockhounds Kansas City',
#   'city': 'Kansas City',
#   'url': 'https://showmerockhounds.com/',
#   'state': 'Missouri'},
#  {'name': 'Billings Gem & Mineral Club, Inc.',
#   'city': 'Billings',
#   'url': 'http://www.billingsgemclub.com/',
#   'state': 'Montana'},
#  {'name': 'Bitterroot Gem & Mineral Society',
#   'city': 'Corvallis',
#   'url': 'http://www.ravalligemandmineralclub.org/',
#   'state': 'Montana'},
#  {'name': 'Bozeman Gem and Mineral Club',
#   'city': 'Bozeman',
#   'url': 'http://bozemangemandmineralclub.com/',
#   'state': 'Montana'},
#  {'name': 'Hellgate Mineral Society',
#   'city': 'Missoula',
#   'url': 'https://www.facebook.com/HellgateMineralSociety/',
#   'state': 'Montana'},
#  {'name': 'Kalispell Rockhound Club',
#   'city': 'Kalispell',
#   'url': 'http://www.kalispellrockhounds.org/',
#   'state': 'Montana'},
#  {'name': 'Lincoln Gem & Mineral Club, Inc.',
#   'city': 'Lincoln',
#   'url': 'https://www.lincolngemmineralclub.org/',
#   'state': 'Nebraska'},
#  {'name': 'Comstock Gold Prospectors',
#   'city': 'Reno',
#   'url': 'http://cgpgold.org/',
#   'state': 'Nevada'},
#  {'name': 'Great Basin Gem & Mineral Club',
#   'city': 'Carson City',
#   'url': 'http://greatbasingemandmineralclub.rocks/',
#   'state': 'Nevada'},
#  {'name': 'High Desert Rockers',
#   'city': 'Carson City',
#   'url': 'https://highdesertrockers.wordpress.com/',
#   'state': 'Nevada'},
#  {'name': 'Nye Gold Seekers',
#   'city': 'Pahrump',
#   'url': 'http://nyegoldseekers.webs.com/',
#   'state': 'Nevada'},
#  {'name': 'Reno Gem and Mineral Society',
#   'city': 'Reno',
#   'url': 'http://www.renorockhounds.com/',
#   'state': 'Nevada'},
#  {'name': 'Southern Nevada Gem and Mineral Society',
#   'city': 'Las Vegas',
#   'url': 'http://www.snvgms.org/',
#   'state': 'Nevada'},
#  {'name': 'Capital Mineral Club',
#   'city': 'Concord',
#   'url': 'http://www.capitalmineralclub.org/',
#   'state': 'New Hampshire'},
#  {'name': 'Keene Mineral Club',
#   'city': 'Keene',
#   'url': 'https://sites.google.com/site/keenemineralclub/home',
#   'state': 'New Hampshire'},
#  {'name': 'Saco Valley Gem and Mineral Club',
#   'city': 'Conway',
#   'url': 'http://www.sacovalleygemandmineralclub.org/',
#   'state': 'New Hampshire'},
#  {'name': 'Southeastern New Hampshire Mineral Club',
#   'city': 'Dover',
#   'url': 'https://www.senhmc.org/',
#   'state': 'New Hampshire'},
#  {'name': 'Cape Atlantic Rockhounds Inc.',
#   'city': 'Cologne',
#   'url': 'http://www.capeatlanticrockhounds.com/',
#   'state': 'New Jersey'},
#  {'name': 'Delaware Valley Earth Science Society',
#   'city': 'Woodbury',
#   'url': 'http://www.dvess.org/',
#   'state': 'New Jersey'},
#  {'name': 'Friends of Mineralogy - New Jersey Chapter',
#   'city': 'Marlboro Township',
#   'url': 'https://fomnj.wordpress.com/',
#   'state': 'New Jersey'},
#  {'name': 'Morris Museum Mineralogical Society',
#   'city': 'Morristown',
#   'url': 'http://morrismuseum.org/mineral-society/',
#   'state': 'New Jersey'},
#  {'name': 'New Jersey Mineralogical Society, Inc',
#   'city': 'Mountainside',
#   'url': 'http://www.njmin.org/',
#   'state': 'New Jersey'},
#  {'name': 'North Jersey Mineralogical Society, Inc.',
#   'city': 'Paterson',
#   'url': 'http://www.nojms.webs.com/',
#   'state': 'New Jersey'},
#  {'name': 'Albuquerque Gem & Mineral Club',
#   'city': 'Albuquerque',
#   'url': 'http://www.agmc.info/',
#   'state': 'New Mexico'},
#  {'name': 'Carlsbad Gem and Mineral Society',
#   'city': 'Carlsbad',
#   'url': 'http://www.carlsbadgms.org/',
#   'state': 'New Mexico'},
#  {'name': 'Deming Gem & Mineral Society',
#   'city': 'Deming',
#   'url': 'http://www.thedgms.com/',
#   'state': 'New Mexico'},
#  {'name': 'Grant County Rolling Stones Gem & Mineral Society, Inc.',
#   'city': 'Silver City',
#   'url': 'http://rollingstonesgms.blogspot.com/',
#   'state': 'New Mexico'},
#  {'name': 'Los Alamos Geological Society',
#   'city': 'Los Alamos',
#   'url': 'http://pweb.netcom.com/~hoffmans/LAGS.html',
#   'state': 'New Mexico'},
#  {'name': 'Buffalo Geological Society, Inc.',
#   'city': 'Buffalo',
#   'url': 'http://www.bgsny.org/',
#   'state': 'New York'},
#  {'name': 'Capital District Mineral Club',
#   'city': 'Albany',
#   'url': 'http://capitaldistrictmineralclub.com/',
#   'state': 'New York'},
#  {'name': 'Gem and Mineral Society of Syracuse, Inc.',
#   'city': 'Syracuse',
#   'url': 'http://www.gmss.us/',
#   'state': 'New York'},
#  {'name': 'Island Rockhounds Inc.',
#   'city': 'Bellmore',
#   'url': 'http://www.islandrockhounds.org/',
#   'state': 'New York'},
#  {'name': 'Long Island Mineral & Geology Society',
#   'city': 'Jamesport',
#   'url': 'http://www.limineralandgeology.com/LiMags/Home.html',
#   'state': 'New York'},
#  {'name': 'Mid-Hudson Valley Gem and Mineral Society Inc.',
#   'city': 'Poughkeepsie',
#   'url': 'http://mhvgms.org/index.html',
#   'state': 'New York'},
#  {'name': 'Nassau Mineral Club',
#   'city': 'Glen Cove',
#   'url': 'http://nassaumineralclub.org/',
#   'state': 'New York'},
#  {'name': 'New York Mineralogical Club',
#   'city': 'NYC',
#   'url': 'http://www.newyorkmineralogicalclub.org/',
#   'state': 'New York'},
#  {'name': 'New York Paleontological Society',
#   'city': 'NYC',
#   'url': 'http://www.nyps.org/index.htm',
#   'state': 'New York'},
#  {'name': 'Orange County Mineral Society',
#   'city': 'Middletown',
#   'url': 'http://www.orangecountymineralsocietynewyork.com/',
#   'state': 'New York'},
#  {'name': 'Rochester Academy of Science',
#   'city': 'Rochester',
#   'url': 'http://www.rasny.org/',
#   'state': 'New York'},
#  {'name': 'Rochester Lapiday Society',
#   'city': 'Rochester',
#   'url': 'http://www.rochesterlapidary.org/',
#   'state': 'New York'},
#  {'name': 'St. Lawrence County Rock & Mineral Club',
#   'city': 'Canton',
#   'url': 'http://stlawrencecountymineralclub.org/',
#   'state': 'New York'},
#  {'name': 'Suffolk Gem & Mineral Club',
#   'city': 'Bay Shore',
#   'url': 'http://www.suffolkgem.com/',
#   'state': 'New York'},
#  {'name': 'Wayne County Gem and Mineral Club',
#   'city': 'Newark',
#   'url': 'http://www.wcgmc.org/',
#   'state': 'New York'},
#  {'name': 'Cape Fear Mineral & Gem Society',
#   'city': 'Fayetteville',
#   'url': 'http://www.mercergarden.com/GemClub.html',
#   'state': 'North Carolina'},
#  {'name': 'Catawba Valley Gem & Mineral Club',
#   'city': 'Hickory',
#   'url': 'http://www.cvgmc.com/',
#   'state': 'North Carolina'},
#  {'name': 'Central North Carolina Mineral Club',
#   'city': 'Chapel Hill',
#   'url': 'http://www.centralncmineralclub.org/',
#   'state': 'North Carolina'},
#  {'name': 'Charlotte Gem & Mineral Club',
#   'city': 'Charlotte',
#   'url': 'http://www.charlottegem.com/',
#   'state': 'North Carolina'},
#  {'name': 'Forsyth Gem and Mineral Club',
#   'city': 'Winston-Salem',
#   'url': 'http://www.forsythgemclub.com/fgmcmain.html',
#   'state': 'North Carolina'},
#  {'name': 'Gaston Gem, Mineral and Faceters Club',
#   'city': 'Gastonia',
#   'url': 'http://gastongemclub.weebly.com/',
#   'state': 'North Carolina'},
#  {'name': 'Gem & Mineral Society of Franklin',
#   'city': 'Franklin',
#   'url': 'http://www.fgmm.org/',
#   'state': 'North Carolina'},
#  {'name': 'Greensboro Gem & Mineral Club',
#   'city': 'Greensboro',
#   'url': 'http://www.ggmc-rockhounds.com/',
#   'state': 'North Carolina'},
#  {'name': 'Henderson County Gem and Mineral Society',
#   'city': 'Hendersonville',
#   'url': 'http://hcgms.com/index.html',
#   'state': 'North Carolina'},
#  {'name': 'Mountain Area Gem and Mineral Association (MAGMA)',
#   'city': 'Asheville',
#   'url': 'http://www.wncrocks.com/magma/magma.html',
#   'state': 'North Carolina'},
#  {'name': 'North Carolina Fossil Club',
#   'city': 'Raleigh',
#   'url': 'http://www.ncfossilclub.org/',
#   'state': 'North Carolina'},
#  {'name': 'Southern Appalachian Mineral Society',
#   'city': 'Asheville',
#   'url': 'http://www.main.nc.us/sams/',
#   'state': 'North Carolina'},
#  {'name': 'Tar Heel Gem & Mineral Club',
#   'city': 'Raleigh',
#   'url': 'http://www.tarheelclub.org/',
#   'state': 'North Carolina'},
#  {'name': 'Central Dakota Gem & Mineral Society',
#   'city': 'Bismarck',
#   'url': 'https://ndrockclub.org/',
#   'state': 'North Dakota'},
#  {'name': 'Brukner Gem and Mineral Club',
#   'city': 'Troy',
#   'url': 'http://www.bruknergemandmineralclub.com/',
#   'state': 'Ohio'},
#  {'name': 'Cincinnati Mineral Society',
#   'city': 'Cincinnati',
#   'url': 'http://mineralsociety.org/',
#   'state': 'Ohio'},
#  {'name': 'Columbus Rock and Mineral Society',
#   'city': 'Columbus',
#   'url': 'http://www.columbusrockandmineralsociety.org/',
#   'state': 'Ohio'},
#  {'name': 'Dayton Gem & Mineral Society',
#   'city': 'Kettering',
#   'url': 'https://www.facebook.com/The-Dayton-Gem-Mineral-Society-140478502678195/',
#   'state': 'Ohio'},
#  {'name': 'Dry Dredgers',
#   'city': 'Cincinnati',
#   'url': 'http://drydredgers.org/',
#   'state': 'Ohio'},
#  {'name': 'Greater Cincinati Lapidary and Faceting Society',
#   'city': 'Loveland',
#   'url': 'http://cincinnatilapidary.weebly.com/',
#   'state': 'Ohio'},
#  {'name': 'North Coast Fossil Club',
#   'city': 'Cleveland',
#   'url': 'http://ncfclub.org/',
#   'state': 'Ohio'},
#  {'name': 'Ohio Geological Society',
#   'city': 'Worthington',
#   'url': 'https://ohiogeosoc.org/',
#   'state': 'Ohio'},
#  {'name': 'Parma Lapidary Club',
#   'city': 'Cleveland',
#   'url': 'http://www.parmalapidary.com/',
#   'state': 'Ohio'},
#  {'name': 'Richland Lithic & Lapidary Society',
#   'city': 'Mansfield',
#   'url': 'http://rlls.webs.com/',
#   'state': 'Ohio'},
#  {'name': 'Summit Lapidary Club',
#   'city': 'Cuyahoga Falls',
#   'url': 'http://lapidaryclubofohio.org/',
#   'state': 'Ohio'},
#  {'name': 'Toledo Gem & Rockhound Club',
#   'city': 'Toledo',
#   'url': 'http://rockyreader.com/',
#   'state': 'Ohio'},
#  {'name': 'Ada Gem, Mineral and Fossil Club',
#   'city': 'Ada',
#   'url': 'http://www.freewebs.com/agmfc/',
# ...
#   'url': 'http://www.rasloto.com/FM/',
#   'state': 'Pennsylvania'},
#  {'name': 'Gem City Rock and Mineral Society',
#   'city': 'Erie',
#   'url': 'http://www.gemcityrockclub.org/',
#   'state': 'Pennsylvania'},
#  {'name': 'Leidy Microscopical Society',
#   'city': 'Fairless Hills',
#   'url': 'http://leidymicroscopical.com/',
#   'state': 'Pennsylvania'},
#  {'name': 'Mason-Dixon Rock, Mineral, Gemological, & Lapidary Club',
#   'city': 'Hanover',
#   'url': 'http://topgemz.com/',
#   'state': 'Pennsylvania'},
#  {'name': 'Mineralogical Society of Northeastern Pennsylvania',
#   'city': 'Moosic',
#   'url': 'http://msnepa.org/',
#   'state': 'Pennsylvania'},
#  {'name': 'Monongahela Rockhounds',
#   'city': 'Pittsburgh',
#   'url': 'http://www.monongahelarockhounds.org/',
#   'state': 'Pennsylvania'},
#  {'name': 'Monroe County Earth Science Association',
#   'city': 'Stroudsburg',
#   'url': 'http://www.mdsysconsulting.com/MCESA/',
#   'state': 'Pennsylvania'},
#  {'name': 'Moraine Rockbusters',
#   'city': 'Mars',
#   'url': 'http://www.morainerockbusters.org/',
#   'state': 'Pennsylvania'},
#  {'name': 'Nittany Mineralogical Society',
#   'city': 'State College',
#   'url': 'http://www.nittanymineral.org/',
#   'state': 'Pennsylvania'},
#  {'name': 'Pennsylvania Earth Sciences Association',
#   'city': 'Whitehall',
#   'url': 'http://www.mineralfest.com/',
#   'state': 'Pennsylvania'},
#  {'name': 'Philadelphia Mineralogical Society',
#   'city': 'Philadelphia',
#   'url': 'http://www.phillyrocks.org/',
#   'state': 'Pennsylvania'},
#  {'name': 'Pittsburgh Geological Society',
#   'city': 'Pittsburgh',
#   'url': 'http://www.pittsburghgeologicalsociety.org/index.html',
#   'state': 'Pennsylvania'},
#  {'name': 'Tuscarora Lapidary Society',
#   'city': 'Brookhaven',
#   'url': 'http://www.lapidary.org/',
#   'state': 'Pennsylvania'},
#  {'name': 'Rhode Island Mineral Hunters, Inc.',
#   'city': 'Warwick',
#   'url': 'http://rimh.us/',
#   'state': 'Rhode Island'},
#  {'name': 'Aiken Gem and Mineral Society',
#   'city': 'Aiken',
#   'url': 'http://www.aikengmfs.org/',
#   'state': 'South Carolina'},
#  {'name': 'Columbia Gem & Mineral Society',
#   'city': 'Columbia',
#   'url': 'http://www.cgams.org/',
#   'state': 'South Carolina'},
#  {'name': 'Lowcountry Gem and Mineral Society',
#   'city': 'North Charleston',
#   'url': 'http://lowcountrygemandmineralsociety.org/',
#   'state': 'South Carolina'},
#  {'name': 'Pendleton District Gem and Mineral Society',
#   'city': 'Central',
#   'url': 'http://www.woodsmere.com/pdgms/',
#   'state': 'South Carolina'},
#  {'name': 'Western South Carolina Gem and Mineral Society',
#   'city': 'Greenville',
#   'url': 'http://www.wescagem.org/',
#   'state': 'South Carolina'},
#  {'name': 'Sioux Empire Gem and Mineral Society',
#   'city': 'Sioux Falls',
#   'url': 'http://www.segams.org/',
#   'state': 'South Dakota'},
#  {'name': 'Western Dakota Gem & Mineral Society',
#   'city': 'Rapid City',
#   'url': 'http://www.wdgms.org/',
#   'state': 'South Dakota'},
#  {'name': 'Knoxville Gem & Mineral Society',
#   'city': 'Knoxville',
#   'url': 'http://www.knoxrocks.org/',
#   'state': 'Tennessee'},
#  {'name': 'Memphis Archaeological & Geological Society',
#   'city': 'Memphis',
#   'url': 'http://www.memphisgeology.org/',
#   'state': 'Tennessee'},
#  {'name': 'Middle Tennessee Rockhounds',
#   'city': 'Nashville',
#   'url': 'http://www.rockhound.org/',
#   'state': 'Tennessee'},
#  {'name': 'Mid-Tennessee Gem and Mineral Society',
#   'city': 'Murfreesboro, Donelson, Tullahoma',
#   'url': 'http://www.mtgms.org/',
#   'state': 'Tennessee'},
#  {'name': 'Arlington Gem and Mineral Club',
#   'city': 'Arlington',
#   'url': 'http://www.agemclub.org/',
#   'state': 'Texas'},
#  {'name': 'Austin Gem and Mineral Society',
#   'city': 'Austin',
#   'url': 'http://www.austingemandmineral.org/index.html',
#   'state': 'Texas'},
#  {'name': 'Central Texas Gem & Mineral Society',
#   'city': 'Abilene',
#   'url': 'http://rockclub.txol.net/',
#   'state': 'Texas'},
#  {'name': 'Chihuahuan Desert Gem and Mineral Club',
#   'city': 'Alpine',
#   'url': 'http://www.cdgmc.org/',
#   'state': 'Texas'},
#  {'name': 'Clear Lake Gem and Mineral Society',
#   'city': 'Houston',
#   'url': 'http://www.clgms.org/',
#   'state': 'Texas'},
#  {'name': 'Cowtown Gem, Mineral & Glass Society',
#   'city': 'Fort Worth',
#   'url': 'http://cera-fw.org/gem-mineral-glass/',
#   'state': 'Texas'},
#  {'name': 'Dallas Gem and Mineral Society',
#   'city': 'Dallas',
#   'url': 'http://www.dallasgemandmineral.org/',
#   'state': 'Texas'},
#  {'name': 'Dallas Paleontological Society',
#   'city': 'Dallas',
#   'url': 'https://dps.wildapricot.org/',
#   'state': 'Texas'},
#  {'name': 'East Texas Gem and Mineral Society',
#   'city': 'Tyler',
#   'url': 'http://www.etgms.com/',
#   'state': 'Texas'},
#  {'name': 'El Paso Mineral and Gem Society, Inc.',
#   'city': 'El Paso',
#   'url': 'http://www.epmgs.com/',
#   'state': 'Texas'},
#  {'name': 'Fort Worth Gem and Mineral Club',
#   'city': 'Fort Worth',
#   'url': 'http://www.fortworthgemandmineralclub.org/',
#   'state': 'Texas'},
#  {'name': 'Fredericksburg Rockhounds',
#   'city': 'Fredericksburg',
#   'url': 'http://fredericksburgrockhounds.org/',
#   'state': 'Texas'},
#  {'name': 'Geological Society of San Antonio',
#   'city': 'San Antonio',
#   'url': 'http://www.geosa.org/',
#   'state': 'Texas'},
#  {'name': 'Golden Spread Gem, Mineral and Treasure Society',
#   'city': 'Amarillo',
#   'url': 'http://www.amarillotreasure.com/',
#   'state': 'Texas'},
#  {'name': 'Gulf Coast Gem & Mineral Society',
#   'city': 'Corpus Christi',
#   'url': 'http://www.gcgms.org/',
#   'state': 'Texas'},
#  {'name': 'Houston Gem and Mineral Society',
#   'city': 'Houston',
#   'url': 'http://www.hgms.org/',
#   'state': 'Texas'},
#  {'name': 'Lubbock Gem and Mineral Society',
#   'city': 'Lubbock',
#   'url': 'http://www.lubbockgemandmineral.org/',
#   'state': 'Texas'},
#  {'name': 'Midland Gem and Mineral Society, Inc.',
#   'city': 'Midland',
#   'url': 'https://www.facebook.com/midlandgemandmineral/',
#   'state': 'Texas'},
#  {'name': 'Oak Cliff Gem and Mineral Society',
#   'city': 'Dallas',
#   'url': 'http://www.ocgemandmineral.com/',
#   'state': 'Texas'},
#  {'name': 'Paleontological Society of Austin',
#   'city': 'Austin',
#   'url': 'http://www.austinpaleo.org/',
#   'state': 'Texas'},
#  {'name': 'Pine Country Gem & Mineral Society',
#   'city': 'Jasper',
#   'url': 'http://www.pinecountry-gms.org/',
#   'state': 'Texas'},
#  {'name': 'Piney Woods Gem & Mineral Society',
#   'city': 'Huntsville',
#   'url': 'http://www.pwgms.org/',
#   'state': 'Texas'},
#  {'name': 'Pleasant Oaks Gem & Mineral Club',
#   'city': 'Dallas',
#   'url': 'http://www.pogmc.org/',
#   'state': 'Texas'},
#  {'name': "Rollin' Rock Club, Inc.",
#   'city': "Rollin' Rock Club Of Texas And Any Other State Or Country Of The World and Outer Space",
#   'url': 'https://sites.google.com/site/rollinrockclub/',
#   'state': 'Texas'},
#  {'name': 'South Texas Geological Society',
#   'city': 'San Antonio',
#   'url': 'http://www.stgs.org/',
#   'state': 'Texas'},
#  {'name': 'Southwest Gem and Mineral Society',
#   'city': 'San Antonio',
#   'url': 'http://www.swgemandmineral.org/',
#   'state': 'Texas'},
#  {'name': 'Texas Faceters Guild',
#   'city': 'Houston',
#   'url': 'http://texasfacetersguild.org/',
#   'state': 'Texas'},
#  {'name': 'Tri-City Gem and Mineral Society, Inc.',
#   'city': 'Temple',
#   'url': 'https://www.facebook.com/midlandgemandmineral/',
#   'state': 'Texas'},
#  {'name': 'Waco Gem and Mineral Club',
#   'city': 'Waco',
#   'url': 'http://www.wacogemandmineral.org/',
#   'state': 'Texas'},
#  {'name': 'Williamson County Gem and Mineral Society',
#   'city': 'Georgetown',
#   'url': 'http://www.wcgms.org/',
#   'state': 'Texas'},
#  {'name': 'Wise County Fossil, Rock and Mineral Society',
#   'city': 'Decatur',
#   'url': 'http://wisecofossilrockandmineralsoc.weebly.com/',
#   'state': 'Texas'},
#  {'name': 'Beehive Rock and Gem Club',
#   'city': 'Ogden',
#   'url': 'http://www.beehiverockandgem.com/',
#   'state': 'Utah'},
#  {'name': 'Cache Rock and Gem Club',
#   'city': 'Smithfield',
#   'url': 'http://cacherockgemclub.weebly.com/',
#   'state': 'Utah'},
#  {'name': 'Golden Spike Gem & Mineral Society',
#   'city': 'Ogden',
#   'url': 'http://goldenspikegem.org/',
#   'state': 'Utah'},
#  {'name': 'Mineral Collectors of Utah',
#   'city': 'Salt Lake City',
#   'url': 'http://m-c-u.org/',
#   'state': 'Utah'},
#  {'name': 'Moab Rock Club',
#   'city': 'Moab',
#   'url': 'https://www.facebook.com/Moab-Rock-Club-1508131859497762/',
#   'state': 'Utah'},
#  {'name': 'Rockhounders Outreach for Community Knowledge',
#   'city': 'Sandy',
#   'url': 'http://www.rockhoundersock.com/',
#   'state': 'Utah'},
#  {'name': 'Timpanogos Gem & Mineral Society',
#   'city': 'Provo',
#   'url': 'http://timprocks.weebly.com/',
#   'state': 'Utah'},
#  {'name': 'Tooele Gem & Mineral Society',
#   'city': 'Tooele',
#   'url': 'https://www.facebook.com/Tooele-Gem-Mineral-Society-1742342656045404/',
#   'state': 'Utah'},
#  {'name': 'Wasatch Gem Society',
#   'city': 'Salt Lake City',
#   'url': 'http://www.wasatchgemsociety.com/',
#   'state': 'Utah'},
#  {'name': 'Burlington Gem and Mineral Club',
#   'city': 'Burlington',
#   'url': 'http://www.burlingtongemandmineralclub.org/',
#   'state': 'Vermont'},
#  {'name': 'Rutland Rock & Mineral Club',
#   'city': 'Rutland',
#   'url': 'http://www.rutlandrockmineralclub.50webs.com/',
#   'state': 'Vermont'},
#  {'name': 'Gem and Mineral Hunters, Inc.',
#   'city': 'Manassas',
#   'url': 'http://www.gmhonline.org/',
#   'state': 'Virginia'},
#  {'name': 'Gem and Mineral Society of Lynchburg',
#   'city': 'Lynchburg',
#   'url': 'http://www.lynchburgrockclub.org/',
#   'state': 'Virginia'},
#  {'name': 'Gem and Mineral Society of the Virginia Peninsula',
#   'city': 'Hampton',
#   'url': 'http://www.gmsvp.org/',
#   'state': 'Virginia'},
#  {'name': 'Northern Virginia Mineral Club, Inc.',
#   'city': 'Arlington',
#   'url': 'http://www.novamineralclub.org/',
#   'state': 'Virginia'},
#  {'name': 'Richmond Gem & Mineral Society',
#   'city': 'Richmond',
#   'url': 'http://www.rgms-va.info/',
#   'state': 'Virginia'},
#  {'name': 'Roanoke Valley Mineral & Gem Society',
#   'city': 'Roanoke',
#   'url': 'https://www.facebook.com/RVMGS/',
#   'state': 'Virginia'},
#  {'name': 'Shenandoah Valley Gem & Mineral Society',
#   'city': 'Waynesboro',
#   'url': 'http://www.shenandoahvalleyrockclub.org/',
#   'state': 'Virginia'},
#  {'name': 'Tidewater Gem & Mineral Society',
#   'city': 'Virginia Beach',
#   'url': 'http://tgms.weebly.com/',
#   'state': 'Virginia'},
#  {'name': 'Bellevue Rock Club, Inc.',
#   'city': 'Bellevue',
#   'url': 'http://www.bellevuerockclub.org/',
#   'state': 'Washington'},
#  {'name': 'Cascade Mineralogical Society Inc',
#   'city': 'Kent',
#   'url': 'http://www.cascademineralogicalsociety.org/',
#   'state': 'Washington'},
#  {'name': 'Clallam County Gem & Mineral Association',
#   'city': 'Port Angeles',
#   'url': 'http://www.olympicrocks.com/',
#   'state': 'Washington'},
#  {'name': 'Darrington Rock & Gem Club',
#   'city': 'Darrington',
#   'url': 'https://www.facebook.com/DarringtonRGC/',
#   'state': 'Washington'},
#  {'name': 'East KingCo Rock Club',
#   'city': 'Kirkland',
#   'url': 'http://www.eastkingco.org/',
#   'state': 'Washington'},
#  {'name': 'Everett Rock & Gem Club',
#   'city': 'Everett',
#   'url': 'http://www.everettrockclub.com/',
#   'state': 'Washington'},
#  {'name': 'Ginkgo Mineral Society',
#   'city': 'Wenatchee',
#   'url': 'http://wenatcheerockclub.org/',
#   'state': 'Washington'},
#  {'name': 'Kitsap Mineral and Gem Societ',
#   'city': 'Bremerton',
#   'url': 'http://www.kmgs.org/',
#   'state': 'Washington'},
#  {'name': 'Lakeside Gem & Mineral Club, Inc.',
#   'city': 'Kennewick',
#   'url': 'http://www.lakesidegemandmineralclub.com/',
#   'state': 'Washington'},
#  {'name': 'Maplewood Rock & Gem Community Club',
#   'city': 'Edmonds',
#   'url': 'http://www.maplewoodrockclub.com/',
#   'state': 'Washington'},
#  {'name': 'Marcus Whitman Gem and Mineral Society',
#   'city': 'Walla Walla',
#   'url': 'https://www.sites.google.com/site/mwgemandmineral/',
#   'state': 'Washington'},
#  {'name': 'Marysville Rock & Gem Club, Inc.',
#   'city': 'Marysville',
#   'url': 'https://sites.google.com/site/marysvillerockngemclub/',
#   'state': 'Washington'},
#  {'name': 'Mount Baker Rock And Gem Club',
#   'city': 'Bellingham',
#   'url': 'http://mtbakerrockclub.org/',
#   'state': 'Washington'},
#  {'name': 'North American Miners Association',
#   'city': 'Kent',
#   'url': 'http://www.namaminers.org/',
#   'state': 'Washington'},
#  {'name': 'North Puget Sound Facetors Guild',
#   'city': 'Mount Vernon',
#   'url': 'http://www.facetguild.com/',
#   'state': 'Washington'},
#  {'name': 'Northwest Paleontological Association',
#   'city': 'Puget Sound',
#   'url': 'http://nwpaleo.org/',
#   'state': 'Washington'},
#  {'name': 'Panorama Gem & Mineral Club',
#   'city': 'Arden',
#   'url': 'http://panoramagem.com/',
#   'state': 'Washington'},
#  {'name': 'Puyallup Valley Gem & Mineral Club',
#   'city': 'Puyallup',
#   'url': 'https://www.facebook.com/PuyallupValleyGemClub',
#   'state': 'Washington'},
#  {'name': 'Skagit Rock and Gem Club',
#   'city': 'Mt. Vernon',
#   'url': 'https://www.skagitrockandgem.com/',
#   'state': 'Washington'},
#  {'name': 'Spokane Rock Rollers Club',
#   'city': 'Spokane Valley',
#   'url': 'http://www.rockrollers.org/WP/',
#   'state': 'Washington'},
#  {'name': 'North Seattle Lapidary & Mineral Club',
#   'city': 'Seattle',
#   'url': 'http://www.northseattlerockclub.org',
#   'state': 'Washington'},
#  {'name': 'Washington Agate and Mineral Society',
#   'city': 'Olympia',
#   'url': 'https://wamsolympia.wordpress.com',
#   'state': 'Washington'},
#  {'name': 'West Seattle Rock Club',
#   'city': 'Seattle',
#   'url': 'http://www.westseattlerockclub.org/',
#   'state': 'Washington'},
#  {'name': 'Yakima Rock & Mineral Club',
#   'city': 'Yakima',
#   'url': 'http://www.yakimarockclub.com/',
#   'state': 'Washington'},
#  {'name': 'Kanawha Rock and Gem Club',
#   'city': 'Charleston',
#   'url': 'http://www.kanawharockandgemclub.org/',
#   'state': 'West Virginia'},
#  {'name': 'Prehistoric West Virginia',
#   'city': 'Morgantown',
#   'url': 'http://prehistoricplanet.com/wv/',
#   'state': 'West Virginia'},
#  {'name': 'West Virginia Fossil Club Inc',
#   'city': 'Clarksburg',
#   'url': 'http://www.westvirginiafossilclub.com/',
#   'state': 'West Virginia'},
#  {'name': 'Badger Lapidary & Geological Society, Inc.',
#   'city': 'Monroe',
#   'url': 'http://www.badgerrockclub.org/',
#   'state': 'Wisconsin'},
#  {'name': 'Coulee Rock Club of La Crosse',
#   'city': 'La Crosse',
#   'url': 'https://www.facebook.com/pages/The-Coulee-Rock-Club/182345351787782',
#   'state': 'Wisconsin'},
#  {'name': 'Heart of Wisconsin Gem & Mineral Society',
#   'city': 'Marshfield & Stevens Point',
#   'url': 'https://www.heartofwisconsinrocks.com/',
#   'state': 'Wisconsin'},
#  {'name': 'Kettle Moraine Geological Society',
#   'city': 'Pewaukee',
#   'url': 'http://www.kmgsrocks.com/',
#   'state': 'Wisconsin'},
#  {'name': 'Lakeland Gem Club',
#   'city': 'Minocqua',
#   'url': 'http://www.lakelandgemclub.com/',
#   'state': 'Wisconsin'},
#  {'name': 'Madison Gem and Mineral Club',
#   'city': 'Madison',
#   'url': 'http://www.madisonrockclub.org/',
#   'state': 'Wisconsin'},
#  {'name': 'Northwest Wisconsin Gem & Mineral Society',
#   'city': 'Cameron',
#   'url': 'http://www.cameronamericanlegion.org/rockclub.html',
#   'state': 'Wisconsin'},
#  {'name': 'Oshkosh Earth Science Club',
#   'city': 'Oshkosh',
#   'url': 'https://sites.google.com/site/oshkoshearthscienceclub/home',
#   'state': 'Wisconsin'},
#  {'name': 'Racine Geological Society, Inc',
#   'city': 'Racine',
#   'url': 'http://rgs-wi.tripod.com/',
#   'state': 'Wisconsin'},
#  {'name': "Weis'n'Miners Geology Club",
#   'city': 'Menasha',
#   'url': 'http://www.weismuseum.org/geology-club.html',
#   'state': 'Wisconsin'},
#  {'name': 'Wisconsin Geological Society',
#   'city': 'West Allis',
#   'url': 'http://www.wisgeologicalsociety.com/',
#   'state': 'Wisconsin'},
#  {'name': 'Cody 59ers Rock Club',
#   'city': 'Cody',
#   'url': 'http://www.cody59ers.com/',
#   'state': 'Wyoming'},
#  {'name': 'Riverton Mineral and Gem Society',
#   'city': 'Riverton',
#   'url': 'http://www.rivertonmgs.com/',
#   'state': 'Wyoming'},
#  {'name': 'Wyoming State Mineral and Gem Society',
#   'city': 'Cody',
#   'url': 'http://wymineralandgemsociety.org',
#   'state': 'Wyoming'}]

# %%
import pandas as pd
# Out:
# /Users/ALukpat/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df = pd.DataFrame(rock_list)

# %%
df
# Out:
#                                       name        city  \
# 0       Alabama Mineral & Lapidary Society  Birmingham
# 1                Dothan Gem & Mineral Club      Dothan
# 2       Huntsville Gem and Mineral Society  Huntsville
# 3                Mobile Rock & Gem Society      Mobile
# 4         Montgomery Gem & Mineral Society  Montgomery
# ..                                     ...         ...
# 481             Weis'n'Miners Geology Club     Menasha
# 482           Wisconsin Geological Society  West Allis
# 483                   Cody 59ers Rock Club        Cody
# 484       Riverton Mineral and Gem Society    Riverton
# 485  Wyoming State Mineral and Gem Society        Cody
#
#                                                  url      state
# 0                       http://www.lapidaryclub.com/    Alabama
# 1                http://www.wiregrassrockhounds.com/    Alabama
# 2                          http://huntsvillegms.org/    Alabama
# 3                   http://www.mobilerockandgem.com/    Alabama
# 4    http://montgomerygemandmineralsociety.com/mgms/    Alabama
# ..                                               ...        ...
# 481      http://www.weismuseum.org/geology-club.html  Wisconsin
# 482             http://www.wisgeologicalsociety.com/  Wisconsin
# 483                        http://www.cody59ers.com/    Wyoming
# 484                      http://www.rivertonmgs.com/    Wyoming
# 485                http://wymineralandgemsociety.org    Wyoming
#
# [486 rows x 4 columns]

# %%
df.to_csv('rock-clubs.csv', index=False)
