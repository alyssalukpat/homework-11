# %% [markdown]
# # Texas Tow Trucks (`.apply` and `requests`)
#
# We're going to scrape some [tow trucks in Texas](https://www.tdlr.texas.gov/tools_search/).

# %% [markdown]
# ## Import your imports

# %%
import pandas as pd

from selenium import webdriver
driver = webdriver.Chrome()
driver.get("https://www.tdlr.texas.gov/tools_search/")

# %% [markdown]
# ## Search for the TLDR Number `006565540C`, and scrape the information on that company
#
# Using [license information system](https://www.tdlr.texas.gov/tools_search/), find information about the tow truck number above, displaying the
#
# - The business name
# - Owner/operator
# - Phone number
# - License status (Active, Expired, Etc)
# - Physical address
#
# If you can't figure a 'nice' way to locate something, your two last options might be:
#
# - **Find a "parent" element, then dig inside**
# - **Find all of a type of element** (like we did with `td` before) and get the `[0]`, `[1]`, `[2]`, etc
# - **XPath** (inspect an element, Copy > Copy XPath)
#
# These kinds of techniques tend to break when you're on other result pages, but... maybe not! You won't know until you try.
#
# > - *TIP: When you use xpath, you CANNOT use double quotes or Python will get confused. Use single quotes.*
# > - *TIP: You can clean your data up if you want to, or leave it dirty to clean later*
# > - *TIP: The address part can be tough, but you have a few options. You can use a combination of `.split` and list slicing to clean it now, or clean it later in the dataframe with regular expressions. Or other options, too, probably*

# %%
# click tldr button
tldr_button = driver.find_element_by_id('mcrbutton')
tldr_button.click()

# %%
# click into tldr textbox and input text
textbox = driver.find_element_by_id('mcrdata')
textbox.send_keys('006565540C')

# %%
# click submit
submit_button = driver.find_element_by_id('submit3')
submit_button.click()

# %%
master_table = driver.find_elements_by_tag_name('tr')
company_table = master_table[5].find_element_by_tag_name('td')
name = company_table.text.strip()
name
# Out:
# 'Name:    H & A TOWING LLC'

# %%
owner_getter = master_table[6].find_element_by_tag_name('td')
owner = owner_getter.text.strip()
owner
# Out:
# 'Owner/Officer:   HANEEN ABBAS MOHAMMEDAWI / MANAGER'

# %%
phone_getter = master_table[7].find_element_by_tag_name('td')
phone = phone_getter.text.strip()
phone
# Out:
# 'Phone:   512-999-8883'

# %%
status_getter = master_table[8]
status = status_getter.text.strip()
status
# Out:
# 'Certificate Information: Status:  Active'

# %%
import re

# %%
address_text
# Out:
# 'Carrier Type:  Tow Truck Company\nNumber of Active Tow Trucks:   2\n\nAddress Information\nMailing:\n391 ROAD 51022\nCLEVELAND, TX. 77327\n\nPhysical:\n11710 JOSEPH CLAYTON DR\nAUSTIN, TX. 78753'

# %%
address_getter = master_table[9].find_elements_by_tag_name('td')[1]
address_text = address_getter.text.strip()
address_text2 = re.sub("\n",' ',address_text)
address_regex = r"Physical: (.*)"
address_list = re.findall(address_regex,address_text2)
for item in address_list:
    address = item
address
# Out:
# '11710 JOSEPH CLAYTON DR AUSTIN, TX. 78753'

# %% [markdown]
# # Adapt this to work inside of a single cell
#
# Double-check that it works. You want it to print out all of the details.

# %%
driver.get("https://www.tdlr.texas.gov/tools_search/")

# navigate page, search, submit
tldr_button = driver.find_element_by_id('mcrbutton')
tldr_button.click()
textbox = driver.find_element_by_id('mcrdata')
textbox.send_keys('006565540C')
submit_button = driver.find_element_by_id('submit3')
submit_button.click()

# output info

# company name
master_table = driver.find_elements_by_tag_name('tr')
company_table = master_table[5].find_element_by_tag_name('td')
name_text = company_table.text.strip()
name_regex = r"Name:    (.*)"
name_list = re.findall(name_regex,name_text)
for item in name_list:
    name = item
print(name)

# owner
owner_getter = master_table[6].find_element_by_tag_name('td')
owner_text = owner_getter.text.strip()
owner_regex = r"Owner/Officer:   (.*)"
owner_list = re.findall(owner_regex,owner_text)
for item in owner_list:
    owner = item
print(owner)

# phone
phone_getter = master_table[7].find_element_by_tag_name('td')
phone_text = phone_getter.text.strip()
phone_regex = r"Phone:   (.*)"
phone_list = re.findall(phone_regex,phone_text)
for item in phone_list:
    phone = item
print(phone)

# status
status_getter = master_table[8]
status_text = status_getter.text.strip()
status_regex = r"Certificate Information: Status:  (.*)"
status_list = re.findall(status_regex,status_text)
for item in status_list:
    status = item
print(status)

# address
address_getter = master_table[9].find_elements_by_tag_name('td')[1]
address_text = address_getter.text.strip()
address_text2 = re.sub("\n",' ',address_text)
address_regex = r"Physical: (.*)"
address_list = re.findall(address_regex,address_text2)
for item in address_list:
    address = item
print(address)
# Out:
# H & A TOWING LLC
# HANEEN ABBAS MOHAMMEDAWI / MANAGER
# 512-999-8883
# Active
# 11710 JOSEPH CLAYTON DR AUSTIN, TX. 78753

# %% [markdown]
# # Using .apply to find data about SEVERAL tow truck companies
#
# The file `trucks-subset.csv` has information about the trucks, we'll use it to find the pages to scrape.
#
# ### Open up `trucks-subset.csv` and save it into a dataframe

# %%
df = pd.read_csv('trucks-subset.csv')
df
# Out:
#   TDLR Number
# 0  006565540C
# 1  0654479VSF
# 2  006564940C

# %% [markdown]
# ## Go through each row of the dataset, displaying the URL you will need to scrape for the information on that row
#
# You don't have to actually use the search form for each of these - look at the URL you're on, it has the number in it!
#
# For example, one URL might look like `https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006565540C`.
#
# - *TIP: Use .apply and a function*
# - *TIP: You'll need to build this URL from pieces*
# - *TIP: You probably don't want to `print` unless you're going to fix it for the next question
# - *TIP: pandas won't showing you the entire url! Run `pd.set_option('display.max_colwidth', None)` to display aaaalll of the text in a cell*

# %%
def scrape_trucks(df):
    slug = df['TDLR Number']
    link = f'https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber={slug}'
    print(link)

# %%
df.apply(scrape_trucks, axis=1)
# Out:
# https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006565540C
# https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=0654479VSF
# https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006564940C
# 0    None
# 1    None
# 2    None
# dtype: object

# %% [markdown]
# ### Save this URL into a new column of your dataframe, called `url`
#
# - *TIP: Use a function and `.apply`*
# - *TIP: Be sure to use `return`*

# %%
def scrape_trucks(df):
    slug = df['TDLR Number']
    link = f'https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber={slug}'
    
    data = {}
    data['TDLR_number'] = df['TDLR Number']
    data['url'] = link
    
    return pd.Series(data)

# %%
df.apply(scrape_trucks, axis=1)
# Out:
#   TDLR_number                                                url
# 0  006565540C  https://www.tdlr.texas.gov/tools_search/mccs_d...
# 1  0654479VSF  https://www.tdlr.texas.gov/tools_search/mccs_d...
# 2  006564940C  https://www.tdlr.texas.gov/tools_search/mccs_d...

# %% [markdown]
# ## Go through each row of the dataset, printing out information about each tow truck company.
#
# Now will be **scraping** inside of your function.
#
# - The business name
# - Owner/operator
# - Phone number
# - License status (Active, Expired, Etc)
# - Physical address
#
# Just print it out for now.
#
# - *TIP: use .apply*
# - *TIP: You'll be using the code you wrote before, but converted into a function*
# - *TIP: Remember how the TDLR Number is in the URL? You don't need to do the form submission if you don't want!*
# - *TIP: Make sure you adjust any variables so you don't scrape the same page again and again*

# %%
data = {}
def scrape_trucks(df):
    slug = df['TDLR Number']
    link = f'https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber={slug}'
    driver.get(link)
    
    # company name
    master_table = driver.find_elements_by_tag_name('tr')
    company_table = master_table[5].find_element_by_tag_name('td')
    name_text = company_table.text.strip()
    name_regex = r"Name:    (.*)"
    name_list = re.findall(name_regex,name_text)
    for item in name_list:
        name = item
            
    # owner
    owner_getter = master_table[6].find_element_by_tag_name('td')
    owner_text = owner_getter.text.strip()
    owner_regex = r"Owner/Officer:   (.*)"
    owner_list = re.findall(owner_regex,owner_text)
    for item in owner_list:
        owner = item
    data['owner'] = owner

    # phone
    owner_getter2 = master_table[7].find_element_by_tag_name('td').get_attribute('width')
    if len(owner_getter2) > 0:
        owner_getter = master_table[7].find_element_by_tag_name('td')
        owner_text = owner_getter.text.strip()
        owner_regex = r"Owner/Officer:   (.*)"
        owner_list = re.findall(owner_regex,owner_text)
        for item in owner_list:
            owner2 = item
        owner_getter = master_table[8].find_element_by_tag_name('td')
        owner_text = owner_getter.text.strip()
        owner_regex = r"Owner/Officer:   (.*)"
        owner_list = re.findall(owner_regex,owner_text)
        for item in owner_list:
            owner3 = item
        data['owner'] = owner + " " + owner2 + " " + owner3
        
        phone_getter = master_table[9].find_element_by_tag_name('td')
        phone_text = phone_getter.text.strip()
        phone_regex = r"Phone:   (.*)"
        phone_list = re.findall(phone_regex,phone_text)
        for item in phone_list:
            phone = item
        data['phone'] = phone
            
        count = 10
    else:
        phone_getter = master_table[7].find_element_by_tag_name('td')
        phone_text = phone_getter.text.strip()
        phone_regex = r"Phone:   (.*)"
        phone_list = re.findall(phone_regex,phone_text)
        for item in phone_list:
            phone = item
        data['phone'] = phone
        
        count = 8

    # status
    status_getter = master_table[count]
    status_text = status_getter.text.strip()
    status_regex = r"Certificate Information: Status:  (.*)"
    status_list = re.findall(status_regex,status_text)
    for item in status_list:
        status = item
    
    count = count + 1

    # address
    address_getter = master_table[count].find_elements_by_tag_name('td')[1]
    address_text = address_getter.text.strip()
    address_text2 = re.sub("\n",' ',address_text)
    address_regex = r"Physical: (.*)"
    address_list = re.findall(address_regex,address_text2)
    for item in address_list:
        address = item
    
    data['TDLR_number'] = df['TDLR Number']
    data['url'] = link
    data['company_name'] = name
#     data['owner'] = owner
#     data['phone'] = phone
    data['status'] = status
    data['address'] = address
    
    return pd.Series(data)

# %%
df2 = df.apply(scrape_trucks, axis=1)
df2
# Out:
#                                                                            owner  \
# 0                                             HANEEN ABBAS MOHAMMEDAWI / MANAGER
# 1  SCOTT JENSON / VICE PRESIDENT CHRIS BRENES / PRESIDENT PEERY A HOLMSLEY / CEO
# 2                                                 ABDULRAHMAN Z ALABDULLAH / CEO
#
#           phone TDLR_number  \
# 0  512-999-8883  006565540C
# 1    4325576733  0654479VSF
# 2    2106678546  006564940C
#
#                                                                              url  \
# 0  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006565540C
# 1  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=0654479VSF
# 2  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006564940C
#
#                    company_name  status  \
# 0              H & A TOWING LLC  Active
# 1  24/7 TOWING AND RECOVERY LLC  Active
# 2              A & N TOWING LLC  Active
#
#                                       address
# 0   11710 JOSEPH CLAYTON DR AUSTIN, TX. 78753
# 1  3601 N COUNTY ROAD 1148 MIDLAND, TX. 79705
# 2  10838 DEEPWATER BAY SAN ANTONIO, TX. 78251

# %% [markdown]
# ## Scrape the following information for each row of the dataset, and save it into new columns in your dataframe.
#
# - The business name
# - Owner/operator
# - Phone number
# - License status (Active, Expired, Etc)
# - Physical address
#
# It's basically what we did before, but using the function a little differently.
#
# - *TIP: Same as above, but you'll be returning a `pd.Series` and the `.apply` line is going to be a lot longer*
# - *TIP: Save it to a new dataframe!*
# - *TIP: Make sure you change your `df` variable names correctly if you're cutting and pasting - there are a few so it can get tricky*

# %%
# oops I already did this in the function I just wrote

# %% [markdown]
# ### Save your dataframe as a CSV named `tow-trucks-extended.csv`

# %%
df2.to_csv('tow-trucks-extended.csv', index=False)

# %% [markdown]
# ### Re-open your dataframe to confirm you didn't save any extra weird columns

# %%
pd.set_option("display.max_colwidth", 200)
df3 = pd.read_csv("tow-trucks-extended.csv")
df3.head()
# Out:
#                                                                            owner  \
# 0                                             HANEEN ABBAS MOHAMMEDAWI / MANAGER
# 1  SCOTT JENSON / VICE PRESIDENT CHRIS BRENES / PRESIDENT PEERY A HOLMSLEY / CEO
# 2                                                 ABDULRAHMAN Z ALABDULLAH / CEO
#
#           phone TDLR_number  \
# 0  512-999-8883  006565540C
# 1    4325576733  0654479VSF
# 2    2106678546  006564940C
#
#                                                                              url  \
# 0  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006565540C
# 1  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=0654479VSF
# 2  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006564940C
#
#                    company_name  status  \
# 0              H & A TOWING LLC  Active
# 1  24/7 TOWING AND RECOVERY LLC  Active
# 2              A & N TOWING LLC  Active
#
#                                       address
# 0   11710 JOSEPH CLAYTON DR AUSTIN, TX. 78753
# 1  3601 N COUNTY ROAD 1148 MIDLAND, TX. 79705
# 2  10838 DEEPWATER BAY SAN ANTONIO, TX. 78251

# %% [markdown]
# ## Process the entire `tow-trucks.csv` file
#
# We just did it on a short subset so far. Now try it on all of the tow trucks. **Save as the same filename as before**

# %%
df4 = pd.read_csv('tow-trucks.csv')

# %%
data = {}
def scrape_trucks(df4):
    slug = df4['TDLR Number']
    link = f'https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber={slug}'
    driver.get(link)
    
    # company name
    master_table = driver.find_elements_by_tag_name('tr')
    company_table = master_table[5].find_element_by_tag_name('td')
    name_text = company_table.text.strip()
    name_regex = r"Name:    (.*)"
    name_list = re.findall(name_regex,name_text)
    for item in name_list:
        name = item
            
    # owner
    owner_getter = master_table[6].find_element_by_tag_name('td')
    owner_text = owner_getter.text.strip()
    owner_regex = r"Owner/Officer:   (.*)"
    owner_list = re.findall(owner_regex,owner_text)
    for item in owner_list:
        owner = item
    data['owner'] = owner

    # phone
    # checking if there's a second or third tag with <td width = 400" because only owner name tds have a specific width
    owner_getter2 = master_table[8].find_element_by_tag_name('td').get_attribute('width')
    owner_getter3 = master_table[7].find_element_by_tag_name('td').get_attribute('width')
    if len(owner_getter2) > 0:
        owner_getter = master_table[7].find_element_by_tag_name('td')
        owner_text = owner_getter.text.strip()
        owner_regex = r"Owner/Officer:   (.*)"
        owner_list = re.findall(owner_regex,owner_text)
        for item in owner_list:
            owner2 = item
        owner_getter = master_table[8].find_element_by_tag_name('td')
        owner_text = owner_getter.text.strip()
        owner_regex = r"Owner/Officer:   (.*)"
        owner_list = re.findall(owner_regex,owner_text)
        for item in owner_list:
            owner3 = item
        data['owner'] = owner + " " + owner2 + " " + owner3
        
        phone_getter = master_table[9].find_element_by_tag_name('td')
        phone_text = phone_getter.text.strip()
        phone_regex = r"Phone:   (.*)"
        phone_list = re.findall(phone_regex,phone_text)
        for item in phone_list:
            phone = item
        data['phone'] = phone
            
        count = 10   
        
    elif len(owner_getter3) > 0:
        owner_getter = master_table[7].find_element_by_tag_name('td')
        owner_text = owner_getter.text.strip()
        owner_regex = r"Owner/Officer:   (.*)"
        owner_list = re.findall(owner_regex,owner_text)
        for item in owner_list:
            owner2 = item
        data['owner'] = owner + " " + owner2
        
        phone_getter = master_table[8].find_element_by_tag_name('td')
        phone_text = phone_getter.text.strip()
        phone_regex = r"Phone:   (.*)"
        phone_list = re.findall(phone_regex,phone_text)
        for item in phone_list:
            phone = item
        data['phone'] = phone
            
        count = 9
    
    else:
        phone_getter = master_table[7].find_element_by_tag_name('td')
        phone_text = phone_getter.text.strip()
        phone_regex = r"Phone:   (.*)"
        phone_list = re.findall(phone_regex,phone_text)
        for item in phone_list:
            phone = item
        data['phone'] = phone
        
        count = 8

    # status
    status_getter = master_table[count]
    status_text = status_getter.text.strip()
    status_regex = r"Certificate Information: Status:  (.*)"
    status_list = re.findall(status_regex,status_text)
    for item in status_list:
        status = item
    
    count = count + 1

    # address
    address_getter = master_table[count].find_elements_by_tag_name('td')[1]
    address_text = address_getter.text.strip()
    address_text2 = re.sub("\n",' ',address_text)
    address_regex = r"Physical: (.*)"
    address_list = re.findall(address_regex,address_text2)
    for item in address_list:
        address = item
    
    data['TDLR_number'] = df4['TDLR Number']
    data['url'] = link
    data['company_name'] = name
#     data['owner'] = owner
#     data['phone'] = phone
    data['status'] = status
    data['address'] = address
    
    return pd.Series(data)

# %%
df4 = df4.apply(scrape_trucks, axis=1)

# %%
df4
# Out:
#                                                                                          owner  \
# 0                                                           HANEEN ABBAS MOHAMMEDAWI / MANAGER
# 1                SCOTT JENSON / VICE PRESIDENT CHRIS BRENES / PRESIDENT PEERY A HOLMSLEY / CEO
# 2                                                               ABDULRAHMAN Z ALABDULLAH / CEO
# 3                                        TANYA M JOHNSON / PRESIDENT ROBERT J PETELL / OFFICER
# 4                                                  DANIEL L NASTANSKY / CEO LINDA BRANUM / CEO
# 5                                                                JONNY B MMADUEGBUNA / MANAGER
# 6               MICHAEL THOMAS PHILLIPS / PRESIDENT LAINIE ELIZABETH PHILLIPS / VICE PRESIDENT
# 7                                                                     ADOLFO MARTINEZ JR / CEO
# 8                                                                       MOHAMMAD ALQARNI / CEO
# 9   ANDY ZEWDE JORDAN / MANAGER SAMUEL GEBRESILASSIE LAMBEBO / MANAGER SAHLE W ARAYA / MANAGER
# 10                                                              GAYLYNN G SIZEMORE / PRESIDENT
# 11                                        DHEKRYAT YOUSEF / MANAGER YOUSEF ALMASRI / PRESIDENT
# 12                                                                          FADI DARSAAD / CEO
# 13                                                             CRISTIAN D GONZALEZ / PRESIDENT
# 14                                                                YAZEED M HAMIDEH / PRESIDENT
# 15                                              JUAN F GARCIA / PRESIDENT JOSE E CAMACHO / CEO
# 16                                                                  JANEE M ORMAND / PRESIDENT
# 17                                                                    JANEE M ORMAND / MANAGER
# 18                                                                HELALAH A YOUSEF / PRESIDENT
# 19                                      JASIM M HUSSEIN / PRESIDENT BAHAR A MOHAMMED / MANAGER
#
#            phone TDLR_number  \
# 0   512-999-8883  006565540C
# 1     4325576733  0654479VSF
# 2     2106678546  006564940C
# 3     4693059587  006542079C
# 4     4325575551  0655733VSF
# 5     4697357540  006563128C
# 6   940-627-2800  0655400VSF
# 7     9562357894  006563749C
# 8     7132406665  006539867C
# 9     5129207530  006558372C
# 10    5123053341  0654654VSF
# 11    2815708471  006555702C
# 12    9723659500  006565880C
# 13    7134743228  006563709C
# 14    9723665920  006548464C
# 15    4693484937  006558052C
# 16    5129700856  006551017C
# 17    5129700856  0655102VSF
# 18    2812994974  006545942C
# 19    5129395763  006522893C
#
#                                                                               url  \
# 0   https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006565540C
# 1   https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=0654479VSF
# 2   https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006564940C
# 3   https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006542079C
# 4   https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=0655733VSF
# 5   https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006563128C
# 6   https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=0655400VSF
# 7   https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006563749C
# 8   https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006539867C
# 9   https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006558372C
# 10  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=0654654VSF
# 11  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006555702C
# 12  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006565880C
# 13  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006563709C
# 14  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006548464C
# 15  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006558052C
# 16  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006551017C
# 17  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=0655102VSF
# 18  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006545942C
# 19  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006522893C
#
#                             company_name   status  \
# 0                       H & A TOWING LLC   Active
# 1           24/7 TOWING AND RECOVERY LLC   Active
# 2                       A & N TOWING LLC   Active
# 3                          AR TOWING LLC   Active
# 4           BEST IN THE WEST TOWING, LLC   Active
# 5                    BOUNCING TOWING LLC   Active
# 6   ALL AMERICAN TOWING AND RECOVERY INC  Expired
# 7       BROTHERS TOWING AND RECOVERY LLC   Active
# 8               CITYWIDE AUTO TOWING INC   Active
# 9                        DAGI TOWING LLC   Active
# 10           EAGLE TOWING & RECOVERY INC   Active
# 11                   EZ GOING TOWING LLC   Active
# 12                         FD TOWING INC   Active
# 13           FOX TOWING AND RECOVERY LLC   Active
# 14          GEZE TOWING AND ROADSIDE INC   Active
# 15       J & J TEXAS TOWING SERVICE, INC   Active
# 16          J.O. SALVAGE AND TOWING, LLC   Active
# 17          J.O. SALVAGE AND TOWING, LLC   Active
# 18         JP BETTER TOWING SERVICES LLC   Active
# 19                         JZ TOWING LLC   Active
#
#                                                 address
# 0             11710 JOSEPH CLAYTON DR AUSTIN, TX. 78753
# 1            3601 N COUNTY ROAD 1148 MIDLAND, TX. 79705
# 2            10838 DEEPWATER BAY SAN ANTONIO, TX. 78251
# 3             3014 AURORA MIST DR LITTLE ELM, TX. 75068
# 4                  2801 N FREMONT AVE ODESSA, TX. 79764
# 5             3017 ELMBROOK DR GRAND PRAIRIE, TX. 75052
# 6                 2618 S HIGHWAY 287 DECATUR, TX. 76234
# 7                199 NORTH RIATA ROAD LAREDO, TX. 78043
# 8                    3410 DUNVALE RD HOUSTON, TX. 77063
# 9                   11108 GEORGIAN DR AUSTIN, TX. 78753
# 10              610 W FRONT ST STE 300 HUTTO, TX. 78634
# 11  APT 1021 9494 HUMBLE WESTFIELD RD HUMBLE, TX. 77338
# 12             201 PLANTERS RD 24A SUNNYVALE, TX. 75182
# 13         14027 MEMORIAL DR STE 275 HOUSTON, TX. 77079
# 14                     3524 LISTON LN EULESS, TX. 76040
# 15                     1248 REGAL DR GARLAND, TX. 75040
# 16               1239 E FM 1431 MARBLE FALLS, TX. 78654
# 17               1239 E FM 1431 MARBLE FALLS, TX. 78654
# 18                   8410 E HARDY RD HOUSTON, TX. 77093
# 19  3311 TOWERWOOD DR STE 405 FARMERS BRANCH, TX. 75234

# %%
df4.to_csv('tow-trucks-extended.csv', index=False)
